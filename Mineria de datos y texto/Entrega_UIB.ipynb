# %% [markdown]
# <h2 align="center">Ejercicio Investigadores de la UIB</h2> <h3 align="center"> Arturo González Moya</h3>
#
# El ejercicio consiste en acceder a las páginas de la UIB en donde se detallan los datos de los investigadores. De cada uno de ellos se deberá recoger información como el nombre, el género (si es hombre o mujer), el título (Dra., Sr., ...), a qué grupo de investigación pertenece, su currículum vitae breve, que rol tiene en el grupo de investigación, ...

# %% [markdown]
# Lo primero que hacemos es incorporar las herramientas que necesitaremos para realizar esta tarea.

# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import random

# %% [markdown]
# Añadiremos también una función para grabar la información a un fichero y otra para cargar un fichero.

# %%
def dump_data(data, filename):
    with open(filename, "w") as out_file:
        json.dump(data, out_file)

def load_data(filename):
    data = None
    with open(filename, "r") as in_file:
        data = json.load(in_file)
    return data

# %% [markdown]
# Comenzamos con lo que sería el trabajo. La información de los investigadores la podemos encontrar en el siguiente enlace:
#
# url_categorias = "https://www.uib.cat/recerca/estructures/grups/grups_area/id_area=-1%2526npag={}"
#
# desde el que se puede acceder a todos los grupos de investigación. La organización de estos grupos viene en diferentes páginas ya que hay gran cantidad de ellos. Además, la página de la UIB puede estar en castellano, catalán o inglés. Los CV de los investigadores los extraeremos en los 3 idiomas.

# %%
url_categorias = "https://www.uib.cat/recerca/estructures/grups/grups_area/id_area=-1%2526npag={}"

# %% [markdown]
# Usaremos la siguiente función para cargar las páginas web.

# %%
def load_page(url):
    headers = {'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) '\
           'AppleWebKit/537.36 (KHTML, like Gecko) '\
           'Chrome/75.0.3770.80 Safari/537.36'} #Añadimos esto por problemas al cargar las páginas
    pagina_categorias = requests.get(url,headers = headers)
    if pagina_categorias.status_code == 200:
        return BeautifulSoup(pagina_categorias.text,'html5')
    else:
        print("Esta página no existe. Cambiamos a una de la lista")
        return None

# %% [markdown]
# Cargamos la página anterior.

# %%
categorias = load_page(url_categorias)

# %%
categorias
# Out:
# <!DOCTYPE html>
# <html dir="ltr" itemscope="" itemtype="http://schema.org/WebPage" lang="ca"><head>
#   <title itemprop="name">Llista de grups de recerca segons àrea AEI - Grups de recerca - Estructures - R+D+I -  Universitat de les Illes Balears</title>
#   <meta charset="utf-8"/>
#   <meta content="Universitat de les Illes Balears" name="author"/>
#   <meta content="Llista de grups de recerca segons àrea AEI - Grups de recerca - Estructures - R+D+I -  Universitat de les Illes Balears" name="DCTERMS.title"/>
#   <meta content="Universitat de les Illes Balears" name="DCTERMS.creator"/>
#   <meta content="ca" name="DC.language"/>
#   <meta content="all, index, follow" name="robots"/><meta content="always" name="referrer"/>
#   <meta content="39.636344;2.646333" name="ICBM"/>
#   <meta content="39.636344;2.646333" name="geo.position"/>
#   <meta content="ES-PM" name="geo.region"/>
#   <meta content="Universitat de les Illes Balears" name="geo.placename"/>
#
#   <meta content="Llista de grups de recerca segons àrea AEI" name="description"/>
#
#   <meta content="Llista de grups de recerca segons la seva àrea AEI" name="keywords"/><meta content="p1-6FtiA2lPY7dbQY20Rr9aXzWfC6VoxMT4_TZUvmpI" name="google-site-verification"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <!--<meta name="bitly-verification" content="a970b6c501b1">-->
#   <script src="/digitalAssets/extensions/615738-jquery/jquery.js" type="text/javascript"></script><!--[if lt IE 9]>
# <![endif]-->
# <link href="/digitalAssets/extensions/615738-cssdircom/estils-min.css?version=20201103.css" rel="stylesheet" type="text/css"/><!--[if IE 7]>
# <link href="/digitalAssets/extensions/615738-cssdircom/dircom_ie7.css" rel="stylesheet" type="text/css" ><![endif]-->
#
# <script type="text/javascript">
# 	    $(function(){
# 	      (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
# 	      (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
# 	       m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
# 	       })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
# 	      ga('create', 'UA-13062120-7', 'auto');
# 	      ga('require', 'linkid');
# 	      ga('send', 'pageview');
# 	      ga(function(tracker) {
# 	        var page = tracker.get('name');
# 	        if (typeof eventUA !== 'undefined') {
# 	            ga('set', 'nonInteraction', true);
# 	            ga('send', 'event', eventUA);
# 	        };
# 	      });
# 	    });
# 	    </script>
#
# <meta content="portletbridge" name="generator"/>
# <meta content="ca" http-equiv="content-language"/>
#
# <script type="application/ld+json">
# {
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "url": "https://www.uib.cat/",
#   "logo": "/digitalAssets/290/290331_logo_dircom.png"
# }
# </script>
#
# 	<!-- non-retina iPhone pre iOS 7 --><link href="/digitalAssets/291/291306_apple-touch-icon-57-precomposed.png" rel="apple-touch-icon" sizes="57x57"/>
# 	<!-- non-retina iPad pre iOS 7 --><link href="/digitalAssets/291/291307_apple-touch-icon-72-precomposed.png" rel="apple-touch-icon" sizes="72x72"/>
# 	<!-- retina iPhone pre iOS 7 --><link href="/digitalAssets/291/291308_apple-touch-icon-114-precomposed.png" rel="apple-touch-icon" sizes="114x114"/>
# 	<!-- retina iPad pre iOS 7 --><link href="/digitalAssets/291/291309_apple-touch-icon-144-precomposed.png" rel="apple-touch-icon" sizes="144x144"/>
# <!-- retina iPad pre iOS 7 --><link href="" rel="apple-touch-icon" sizes="152x152"/>
# <link href="https://www.uib.es/es/recerca/estructures/grups/grups_area/" hreflang="es" rel="alternate"/>
# <link href="https://www.uib.eu/../../../../research/groups/grups_area/id_area=-1&amp;npag={}" hreflang="en" rel="alternate"/>
# </head>
#
# <body>
#   <div class="uib_title_hidden" id="top"><a accesskey="S" href="#content-zone" tabindex="1">Botar al contingut</a></div>
#
#   <div class="container-fluid layoutCode1 repositoryId104068 siteNodeId134993" id="uib_grid_body">
#
#    <div class="row-fluid" id="uib_header_options">
#           <div id="progress-bar"></div>
#           <div class="row-fluid" id="logotoolsnav">
# 	          <div class="span6" id="titlelogo">
# 	                 <a accesskey="1" href="/" id="logoUIB" tabindex="2">
# 	 <h1 class="sr-only" id="titleSite">Universitat de les Illes Balears</h1>
# </a>
#
# <nav class="menu-mobile">
# 		       	 	<button id="menu-mobile" tabindex="3">
# 						<span></span><span></span><span></span><span></span>
# 					</button>
# 	          	 </nav>
# 	          </div>
# 	          <div class="span14 tools_bar" id="uib_header_tools">
# 	            <div class="row-fluid" id="uib_header" role="banner">
#     <nav class="menubar hidden-phone">
#         <ol id="menu-bar">
#
#         <li><span>Informació dirigida a</span><input class="openclose" id="c615960" type="checkbox"/><label for="c615960" tabindex="4">Obrir/Tancar submenú</label><div class="sub-menu"><section><ol class="offset6 span14"><li><a href="/lauib/Visitants/">Visitants</a></li><li><a href="/lauib/Visitants/Mes-per-a-tu/Estic-dintercanvi-a-la-UIB-preguntes-mes-frequents/">Estudiants de mobilitat</a></li><li><a href="/lauib/Visitants/Mes-per-a-tu/Futurs-estudiants-Comenca-la-millor-etapa-de-la-teva-vida/">Futurs estudiants</a></li><li><a href="https://alu.uib.cat/">Estudiants</a></li><li><a href="https://portal.uib.cat/">Personal d'administració i serveis</a></li><li><a href="https://portal.uib.cat/">Personal docent i investigador</a></li><li><a href="https://sempre.uib.cat/">Alumni</a></li><li><a href="https://diari.uib.cat/Sala-de-premsa/">Sala de premsa</a></li><li><a href="/lauib/Visitants/Mes-per-a-tu/Descobreix-tot-el-que-la-Biblioteca-de-la-UIB-pot-fer-per-tu/">Biblioteca</a></li></ol></section></div></li>
# <li><a href="https://seu.uib.cat" tabindex="5">Seu electrònica</a></li>
# </ol>
#     </nav>
#     <nav class="hidden-print" id="buttons-header"><a href="https://swww.uib.es/portal-info/portal/entry/" id="btn-header-apps" tabindex="6" title="Aula digital, Portal PAS-PDI, UIBdigital">
#            <span class="far fa-user"></span><span class="sr-only">Aula digital, Portal PAS-PDI, UIBdigital</span>
#          </a>
#
#         <a href="/webmail/" id="btn-header-mail" tabindex="7" title="Webmail">
#            <span class="far fa-envelope"></span><span class="sr-only">Webmail</span>
#          </a>
#
#
#     <button id="btn-header-search" tabindex="8" title="Cercador, Directori telefònic, Personal docent, Guia d'experts, Biblioteca, Mapa del web">
#            <span class="fa fa-search"></span><span class="sr-only">Cercador, Directori telefònic, Personal docent, Guia d'experts, Biblioteca, Mapa del web</span>
#          </button>
#        <div class="searchTools">
#          <button id="btn-close-search" title="">
#            <span class="fas fa-times"></span>
#          </button>
#           <form accept-charset="UTF-8" action="/cerca/" id="cse-form" method="get">
#             <input name="cx" type="hidden" value="018085696492821929087:nzzwo4ylkzc"/>
#             <input name="siteUrl" type="hidden" value="uib.cat"/>
#             <label class="uib_hidden" for="q">Cerca:</label>
#             <button class="gsc-search-button" name="sa" type="submit"> <span class="fa fa-search"></span><span>Cerca</span></button>
#             <input class="gsc-input" id="q" name="q" placeholder="Text a cercar" size="12" type="text"/>
#
# 			<input name="siteNodeId" type="hidden" value="135700"/>
#
#           </form>
#
#           <ul class="links-search">
#             <li><a accesskey="t" class="uib_link_directori" href="/cerca/directori/">Directori telefònic</a></li>
# 			<li><a class="uib_link_personaldocent" href="/cerca/personal-docent/">Personal docent</a></li>
#             <li><a class="uib_link_directori_experts" href="/cerca/experts/">Guia d'experts</a></li>
#             <li><a class="uib_link_biblioteca" href="/cerca/Biblioteca/">Biblioteca</a></li>
#             <li><a accesskey="m" class="uib_link_sitemap" href="/?x_ig_aplicacio=webmap" title="Mapa del web">Mapa del web</a></li>
#           </ul>
#        </div><button id="btn-header-font" tabindex="9" title="Font">
#            <span class="fa fa-font"></span><span class="sr-only">Font</span>
#         </button>
#          <div class="fontSize">
#             <button id="decreaseFont" title="Redueix la mida de la font">A<sup>-</sup></button>
#             <button id="resetFont" title="Inicialitza la mida de la font">A</button>
#             <button id="increaseFont" title="Incrementa la mida de la font">A<sup>+</sup></button>
#      </div>
#
#
#
#      <div id="tool_idiomes_search" role="navigation">
#      	<button class="visible-phone" id="languageButton" title="TODO: CHANGE LANGUAGE"><span class="fas fa-globe"></span></button>
#         <ul class="hidden-phone" id="tool_idiomes">
#         <li><a class="" href="https://www.uib.es/es/recerca/estructures/grups/grups_area/" tabindex="10" title="es">
# 		                    Cast</a>
# 						  </li>
# 		                  <li><a class="" href="https://www.uib.eu/../../../../research/groups/grups_area/id_area=-1&amp;npag={}" lang="en" tabindex="11">
# 		                      Eng</a>
# 		                    </li>
# 		                    </ul>
#       </div>
#
#
#        </nav>
#
# </div><!-- /#uibheader -->
#
#
# <nav class="navtop hidden-phone rs_skip rs_preserve">
#             <ol id="menu-navtop">
#             <li><a href="https://estudis.uib.cat/">Aprèn</a><input class="openclose" id="toogle615940" type="checkbox"/><label for="toogle615940">OpenClose</label><div class="sub-menu row-fluid"><section><aside class="linkColumns span6"><div class="card-new"><a href="https://setmanadelpostgrau.uib.cat/?utm_source=Web&amp;utm_medium=Cubo&amp;utm_campaign=SetmanaPostgrau21"><img alt=" " src="/digitalAssets/629/thumbnail_380_380_629240_RECT_cubo1-cat-setmanapostgrau2021.jpg"/><span class="margin-t-1">VI Setmana del Postgrau</span></a></div><div class="card-new"><a href="https://estudis.uib.cat/estudis-de-grau/?utm_source=Web&amp;utm_medium=Cubo&amp;utm_campaign=GrauUIB"><img alt=" " src="/digitalAssets/628/thumbnail_380_380_628878_RECT_cubo1-cat-promocioconeixlauib-graus.jpg"/><span class="margin-t-1">Estudis de grau de la UIB</span></a></div></aside><ol class="span14"><li><a href="https://estudis.uib.cat/estudis-de-grau/">Estudis de grau</a></li><li><a href="https://estudis.uib.cat/estudis-de-master/">Estudis de màster</a></li><li><a href="https://estudis.uib.cat/estudis-de-doctorat/">Estudis de doctorat</a></li><li><a href="https://uom.uib.es/">Universitat Oberta per a Majors</a></li><li><a href="https://estudis.uib.cat/Estudis-propis/">Estudis propis</a></li><li><a href="https://estudis.uib.cat/Cursos-i-tallers/">Cursos i tallers</a></li><li><a href="https://estudis.uib.cat/Beques-i-ajuts/">Beques i ajuts</a></li><li><a href="https://internacional.uib.cat/Mobilitat-i-intercanvi/AlumnatUIB/">Programes de mobilitat</a></li><li><a href="https://estudis.uib.cat/Preguntes-frequents/">Preguntes freqüents</a></li><li><a href="https://estudis.uib.cat/" title="Aprèn">+ informació <span class="sr-only">Aprèn</span></a></li></ol></section></div></li>
# <li><a href="/recerca/">R+D+I</a><input class="openclose" id="toogle615942" type="checkbox"/><label for="toogle615942">OpenClose</label><div class="sub-menu row-fluid"><section><aside class="linkColumns span6"><div class="card-new"><a href="/recerca/Innovam/"><img alt=" " src="/digitalAssets/610/thumbnail_380_380_610709_RECT_Cubos_Desplegable-ApreIn_2020_InnovacioI.png"/><span class="margin-t-1">Innovació UIB</span></a></div><div class="card-new"><a href="/recerca/HRS4R/"><img alt=" " src="/digitalAssets/610/thumbnail_380_380_610710_RECT_Cubos_Desplegable-ApreIn_2020_EstreteIgia-HRS4R.png"/><span class="margin-t-1">Estratègia HRS4R</span></a></div></aside><ol class="span14"><li><a href="/recerca/estructures/grups/">Grups de recerca</a></li><li><a href="/recerca/ajuts/">Ajuts a la recerca</a></li><li><a href="https://ppi.uib.cat">Portal del personal investigador</a></li><li><a href="https://webgrec.uib.es/grec_cat.html">GREC a la UIB</a></li><li><a href="/recerca/HRS4R/">HRS4R - Estratègia RH</a></li><li><a href="/recerca/Innovam/">Innovació</a></li><li><a href="/recerca/Transferim/">Transferència</a></li><li><a href="/recerca/Emprenem/">Emprenedoria</a></li><li><a href="https://culturacientifica.uib.cat/">Cultura científica</a></li><li><a href="/recerca/Innovam/Fundacio-Universitat-Empresa/">Serveis a les empreses </a></li><li><a href="/recerca/" title="R+D+I">+ informació <span class="sr-only">R+D+I</span></a></li></ol></section></div></li>
# <li><a href="/lauib/">Coneix-nos</a><input class="openclose" id="toogle615941" type="checkbox"/><label for="toogle615941">OpenClose</label><div class="sub-menu row-fluid"><section><aside class="linkColumns span6"><div class="card-new"><a href="https://transparencia.uib.cat/"><img alt=" " src="/digitalAssets/610/thumbnail_380_380_610708_RECT_Cubos_Desplegable-Coneix-nos_2020_Portal-de-transpareIncia.png"/><span class="margin-t-1">Portal de transparència</span></a></div><div class="card-new"><a href="/lauib/Viu-la-UIB/"><img alt=" " src="/digitalAssets/610/thumbnail_380_380_610707_RECT_Cubos_Desplegable-Coneix-nos_2020_24-hores.png"/><span class="margin-t-1">24 hores a la UIB</span></a></div></aside><ol class="span14"><li><a href="/lauib/Visitants/">Visitants</a></li><li><a href="/lauib/Govern-i-organitzacio/Organs-de-govern/rector/">El Rector</a></li><li><a href="/lauib/Govern-i-organitzacio/Organs-de-govern/">Òrgans de Govern</a></li><li><a href="/lauib/Govern-i-organitzacio/estructura/Facultats-i-escoles/">Facultats i escoles</a></li><li><a href="/lauib/Govern-i-organitzacio/estructura/Departaments/">Departaments</a></li><li><a href="/lauib/Govern-i-organitzacio/estructura/serveis/">Serveis</a></li><li><a href="/lauib/Govern-i-organitzacio/estructura/">Estructura</a></li><li><a href="/lauib/Visitants/localitzacio/">Localització</a></li><li><a href="https://transparencia.uib.cat/">Portal de transparència</a></li><li><a href="/lauib/" title="Coneix-nos">+ informació <span class="sr-only">Coneix-nos</span></a></li></ol></section></div></li>
# <li><a href="/tot/">Tot</a></li>
# </ol>
#       </nav>
#
# </div>
# 	      </div>
#       </div>
#    <div class="row-fluid" id="uib_grid">
#
#       <div id="uib_missatges_alerta">
# 		<div class="alert alert-info">
# 			<div class="circle circle-info"></div>
# 			<a href="https://estudis.uib.cat/estudis-de-grau/Com-hi-pots-accedir/acces/pbau/" target="_self">
# 					Matrícula a la prova de batxillerat per a l'accés a la Universitat (PBAU). Del 19 al 23 d'abril fins a les 14.00</a>
# 				</div>
# 	<div class="alert alert-green">
# 			<div class="circle circle-info"></div>
# 			<a href="https://coronavirus.uib.cat/" target="_self">
# 					Informació acadèmica i sanitària sobre el coronavirus</a>
# 				</div></div>
#
# <div class="uib_hidden" id="skipnavigation"><a accesskey="2" href="#uib_grid_content">Botar la navegació</a></div>
#
# 	  	  <div class="row-fluid" id="menu-navegacio-seccio">
# 	<nav class="span20 menubanner" id="uib_banner">	<a href="/recerca/">R+D+I</a>
# 	            <div class="menu-navigation" id="menu-navigation">
# 	        <span class="fas fa-plus"></span>
# 	   </div>
# 	</nav>
#
# 	<!-- ocultarMenu  -->
#
# 		<nav class="menu navegacioseccio visible-tablet visible-desktop rs_skip" id="navegacio-seccio">
# 				<ol class="menulist titled_box_bgbox" id="s134877" role="tree">
# <!-- htmlMenuGrupRecerca:  -->
# 			    <li class="dropdown" id="s135000" role="treeitem" tabindex="0"><a href="/recerca/ajuts/" title="Ajuts - R+D+I">Ajuts</a><input class="openclose" id="op135000" type="checkbox"/><label for="op135000">Obri/Tanca</label><ol class="sub-menu exp"><li role="treeitem" tabindex="-1"><a href="/recerca/ajuts/prfom/" title="Programa de foment de la recerca - Ajuts">Programa de foment de la recerca</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/ajuts/autonomics/" title="Programes autonòmics - Ajuts">Programes autonòmics</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/ajuts/estatals/" title="Programes estatals - Ajuts">Programes estatals</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/ajuts/internacionals/" title="Programes internacionals - Ajuts">Programes internacionals</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/ajuts/beques_mobilitat/" title="Beques, contractes i mobilitat - Ajuts">Beques, contractes i mobilitat</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/ajuts/sexennis/" title="Complements retributius - Ajuts">Complements retributius</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/ajuts/internacionalitzacio/" title="Programes per incentivar la internacionalització - Ajuts">Programes per incentivar la internacionalització</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/ajuts/cerca/" title="Cercador de convocatòries - Ajuts">Cercador de convocatòries</a></li>
# </ol></li>
# <li class="dropdown" id="s135010" role="treeitem" tabindex="0"><span>Dades de recerca</span><input class="openclose" id="op135010" type="checkbox"/><label for="op135010">Obri/Tanca</label><ol class="sub-menu exp"><li role="treeitem" tabindex="-1"><a href="/recerca/dades/ranquings/" title="La UIB als rànquings - Dades de recerca">La UIB als rànquings</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/dades/consulta/" title=" Consulta de dades de recerca - Dades de recerca"> Consulta de dades de recerca</a></li>
# <li class="menu-item nivell1 haschildren dropdown" role="treeitem" tabindex="-1"><a href="/recerca/dades/projectes/" title="Projectes de recerca - Dades de recerca">Projectes de recerca</a><input class="openclose" id="op135014" type="checkbox"/><label for="op135014">Obri/Tanca</label><ol class="sub-menu nivell1"><li role="treeitem" tabindex="-2"><a href="/recerca/dades/projectes/internacionals/" title="Projectes internacionals - Projectes de recerca">Projectes internacionals</a></li>
# <li role="treeitem" tabindex="-2"><a href="/recerca/dades/projectes/feder/" title="Projectes FEDER concedits - Projectes de recerca">Projectes FEDER concedits</a></li>
# <li role="treeitem" tabindex="-2"><a class="extern" href="https://obsolet1.uib.es/recerca/ajuts/" title="Canvi de lloc web">Subvencions estatals i autonòmiques concedides</a></li>
# <li role="treeitem" tabindex="-2"><a href="/recerca/dades/projectes/cataleg/" title="Catàleg de projectes - Projectes de recerca">Catàleg de projectes</a></li>
# </ol></li>
# </ol></li>
# <li aria-current="page" class="dropdown selected" id="s134970" role="treeitem" tabindex="0"><a aria-current="page" class="selected" href="/recerca/estructures/" title="Estructures - R+D+I">Estructures</a><input class="openclose" id="op134970" type="checkbox"/><label for="op134970">Obri/Tanca</label><ol class="sub-menu exp"><li aria-selected="true" class="menu-item nivell1 haschildren dropdown selected" role="treeitem" tabindex="-1"><a aria-current="page" class="selected" href="/recerca/estructures/grups/" title="Grups de recerca - Estructures">Grups de recerca</a><input class="openclose" id="op134989" type="checkbox"/><label for="op134989">Obri/Tanca</label><ol class="sub-menu nivell1"><li role="treeitem" tabindex="-2"><a href="/recerca/estructures/grups/cerca_grups/" title="Cerca de grups - Grups de recerca">Cerca de grups</a></li>
# <li aria-selected="true" class="menu-item nivell2 selected" role="treeitem" tabindex="-2"><a aria-current="page" class="selected" href="/recerca/estructures/grups/grups_area/" title="Llista de grups - Grups de recerca">Llista de grups</a></li>
# <li role="treeitem" tabindex="-2"><a href="/recerca/estructures/grups/cerca_produccio/" title="Producció científica - Grups de recerca">Producció científica</a></li>
# </ol></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/estructures/departaments/" title="Departaments - Estructures">Departaments</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/estructures/instituts/" title="Instituts de recerca - Estructures">Instituts de recerca</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/Innovam/Laboratoris/" title="Laboratoris - Estructures">Laboratoris</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/estructures/unitats_suport/" title="Unitats de suport - Estructures">Unitats de suport</a></li>
# <li class="menu-item nivell1 haschildren dropdown" role="treeitem" tabindex="-1"><a href="/recerca/estructures/comissions/" title="Comissions de recerca - Estructures">Comissions de recerca</a><input class="openclose" id="op134971" type="checkbox"/><label for="op134971">Obri/Tanca</label><ol class="sub-menu nivell1"><li class="menu-item nivell2 haschildren dropdown" role="treeitem" tabindex="-2"><a href="/recerca/estructures/comissions/investigacio/" title="Comissió d'Investigació - Comissions de recerca">Comissió d'Investigació</a></li>
# <li role="treeitem" tabindex="-2"><a class="extern" href="https://osr.uib.cat/CAOSR/" title="Canvi de lloc web">Comissió Avaluadora de l'OSR</a></li>
# <li class="menu-item nivell2 haschildren dropdown" role="treeitem" tabindex="-2"><a href="/recerca/estructures/comissions/ceea/" title="Comitè d'Ètica d'Experimentació Animal (CEEA) - Comissions de recerca">Comitè d'Ètica d'Experimentació Animal (CEEA)</a></li>
# <li class="menu-item nivell2 haschildren dropdown" role="treeitem" tabindex="-2"><a href="/recerca/estructures/comissions/bioseguretat/" title="Comitè de Bioseguretat - Comissions de recerca">Comitè de Bioseguretat</a></li>
# <li class="menu-item nivell2 haschildren dropdown" role="treeitem" tabindex="-2"><a href="/recerca/estructures/comissions/cer/" title="Comitè d'Ètica de la Recerca (CER) - Comissions de recerca">Comitè d'Ètica de la Recerca (CER)</a></li>
# <li class="menu-item nivell2 haschildren dropdown" role="treeitem" tabindex="-2"><a href="/recerca/estructures/comissions/cerbi/" title="Comitè d'Ètica de la Recerca Biosanitària (CERBI)  - Comissions de recerca">Comitè d'Ètica de la Recerca Biosanitària (CERBI) </a></li>
# </ol></li>
# </ol></li>
# <li class="dropdown" id="s134931" role="treeitem" tabindex="0"><a href="/recerca/Innovam/" title="Innovació  - R+D+I">Innovació </a><input class="openclose" id="op134931" type="checkbox"/><label for="op134931">Obri/Tanca</label><ol class="sub-menu exp"><li role="treeitem" tabindex="-1"><a href="/recerca/Innovam/Vicerectorat-dInnovacio-i-Relacions-Institucionals/" title="Vicerectorat d'Innovació i Relacions Institucionals - Innovació ">Vicerectorat d'Innovació i Relacions Institucionals</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/Innovam/Fundacio-Universitat-Empresa/" title="Fundació Universitat-Empresa - Innovació ">Fundació Universitat-Empresa</a></li>
# <li class="menu-item nivell1 haschildren dropdown" role="treeitem" tabindex="-1"><span>Estudis propis i formació continuada</span><input class="openclose" id="op134938" type="checkbox"/><label for="op134938">Obri/Tanca</label><ol class="sub-menu nivell1"><li role="treeitem" tabindex="-2"><a href="/recerca/Innovam/Estudis-propis-i-formacio-continuada/Estudis-propis/" title="Estudis propis - Estudis propis i formació continuada">Estudis propis</a></li>
# <li role="treeitem" tabindex="-2"><a href="/recerca/Innovam/Estudis-propis-i-formacio-continuada/Exposicio-publica-destudis-propis/" title="Exposició pública d'estudis propis - Estudis propis i formació continuada">Exposició pública d'estudis propis</a></li>
# </ol></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/Innovam/Laboratoris/" title="Laboratoris - Innovació ">Laboratoris</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/Innovam/Destacam/" title="Destacam - Innovació ">Destacam</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/Innovam/Premis-TalenTIC/" title="Premis TalenTIC - Innovació ">Premis TalenTIC</a></li>
# </ol></li>
# <li class="dropdown" id="s136755" role="treeitem" tabindex="0"><a href="/recerca/Transferim/" title="Transferència - R+D+I">Transferència</a><input class="openclose" id="op136755" type="checkbox"/><label for="op136755">Obri/Tanca</label><ol class="sub-menu exp"><li role="treeitem" tabindex="-1"><a href="/recerca/Transferim/Oficina-de-Transferencia-OTRI/" title="Oficina de Transferència (OTRI) - Transferència">Oficina de Transferència (OTRI)</a></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/Transferim/Sexenni-de-transferencia/" title="Sexenni de transferència - Transferència">Sexenni de transferència</a></li>
# <li class="menu-item nivell1 haschildren dropdown" role="treeitem" tabindex="-1"><a href="/recerca/Transferim/Protegeix-la-teva-recerca/" title="Protegeix la teva recerca - Transferència">Protegeix la teva recerca</a><input class="openclose" id="op134943" type="checkbox"/><label for="op134943">Obri/Tanca</label><ol class="sub-menu nivell1"><li role="treeitem" tabindex="-2"><a href="/recerca/Transferim/Protegeix-la-teva-recerca/Llistat-de-patens-i-models-dutilitat-de-la-UIB/" title="Llistat de patens i models d'utilitat de la UIB - Protegeix la teva recerca">Llistat de patens i models d'utilitat de la UIB</a></li>
# </ol></li>
# <li class="menu-item nivell1 haschildren dropdown" role="treeitem" tabindex="-1"><a href="/recerca/Transferim/Spin-off/" title="Spin-off - Transferència">Spin-off</a><input class="openclose" id="op134955" type="checkbox"/><label for="op134955">Obri/Tanca</label><ol class="sub-menu nivell1"><li role="treeitem" tabindex="-2"><a href="/recerca/Transferim/Spin-off/Llistat-de-Spin-off-de-la-UIB/" title="Llistat de Spin-off de la UIB - Spin-off">Llistat de Spin-off de la UIB</a></li>
# </ol></li>
# <li role="treeitem" tabindex="-1"><a href="/recerca/Transferim/Contractes-i-convenis-de-recerca-art.-83/" title="Contractes i convenis de recerca (art. 83) - Transferència">Contractes i convenis de recerca (art. 83)</a></li>
# </ol></li>
# <li class="dropdown" id="s136756" role="treeitem" tabindex="0"><a href="/recerca/Emprenem/" title="Emprenedoria - R+D+I">Emprenedoria</a><input class="openclose" id="op136756" type="checkbox"/><label for="op136756">Obri/Tanca</label><ol class="sub-menu exp"><li role="treeitem" tabindex="-1"><a href="/recerca/Emprenem/Foment-de-lesperit-emprenedor/" title="Foment de l'esperit emprenedor - Emprenedoria">Foment de l'esperit emprenedor</a></li>
# </ol></li>
#
# </ol>
# </nav>
# 	</div>
#
# <nav class="row-fluid">
# 				<div id="uib_grid_breadcrumb_bar" itemprop="breadcrumb">
# 	                   <a class="breadcrumbLink" href="/">UIB</a> <span class="fas fa-chevron-right"></span> <a class="breadcrumbLink" href="/recerca/">R+D+I</a> <span class="fas fa-chevron-right"></span> <a class="breadcrumbLink" href="/recerca/estructures/">Estructures</a> <span class="fas fa-chevron-right"></span> <a class="breadcrumbLink" href="/recerca/estructures/grups/">Grups de recerca</a> <span class="fas fa-chevron-right"></span> <a class="breadcrumbLink" href="/recerca/estructures/grups/grups_area/">Llista de grups</a>
# </div>
#             	</nav>
# <div class="row-fluid rs-botons">
# 	          <div class="span20 text-right">
# 	          		<div class="botonssocials rs_preserve rs_skip" id="botonsSocials0">
# 		 <div class="btn_wrap">
#                 <button class="print far fa-file-pdf" id="printer" title="Imprimeix"></button>
# 	        <span>Comparteix al: </span>
# 	        <div class="clipzone">
# 	            <a href="https://www.facebook.com/sharer/sharer.php?u=https%3A%2F%2Fwww.uib.cat%2Frecerca%2Festructures%2Fgrups%2Fgrups_area%2F&amp;t=Llista+de+grups+de+recerca+segons+%C3%A0rea+AEI" title="Comparteix al Facebook">
#    				 <span class="fab fa-facebook-f"><span class="sr-only">Facebook</span></span></a>
#
#
# 	            <a href="https://twitter.com/intent/tweet?tw_p=tweetbutton&amp;url=https%3A%2F%2Fwww.uib.cat%2Frecerca%2Festructures%2Fgrups%2Fgrups_area%2F&amp;text=Llista+de+grups+de+recerca+segons+%C3%A0rea+AEI" title="Comparteix al Twitter">
# 					<span class="fab fa-twitter"><span class="sr-only">Twitter</span></span></a>
#
# 				<a data-action="share/whatsapp/share" href="https://api.whatsapp.com/send?text=https%3A%2F%2Fwww.uib.cat%2Frecerca%2Festructures%2Fgrups%2Fgrups_area%2F" title="Comparteix al Whatsapp">
# 				<span class="fab fa-whatsapp"><span class="sr-only">Whatsapp</span></span></a>
# 	        </div>
# 	    </div>
# 	</div>
#
# <script>
# function doPrint(){
# window.print();
# //printJS({ printable: 'uib_grid', type: 'html', maxWidth:1024, ignoreElements: ['skipnavigation']});
# }
# document.getElementById("printer").addEventListener("click", doPrint);
# </script>
# <script type="text/javascript">
# 		window.rsConf = {params: '//cdn1.readspeaker.com/script/9829/webReader/webReader.js?pids=wr&dload=DocReader.AutoAdd&disable=readhover'};
#
# 		window.rsDocReaderConf = {lang: 'ca_es' ,voice:'Jordi', img_alt: 'Escolta el document'};
# 	</script>
# 	<div id="rspzone">
# 				 <div id="showPlayerRS2020">
# 				 	<div class="rs_skip rsbtn rs_preserve" id="readspeaker_button1">
#
# 					    <a accesskey="L" class="rsbtn_play" href="//app-eu.readspeaker.com/cgi-bin/rsent?customerid=9829&amp;lang=ca_es&amp;voice=Jordi&amp;readid=uib_banner,content-zone&amp;readclass=contentRS&amp;url=https%3A%2F%2Fwww.uib.cat%3A80%2Frecerca%2Festructures%2Fgrups%2Fgrups_area%2F" rel="nofollow" title="Escolta">
# 					        <span class="rsbtn_left rsimg rspart"><span class="rsbtn_text"><span>Escolta</span></span></span>
# 					       </a>
# 					    <button accesskey="r" aria-expanded="false" class="rsbtn_tooltoggle" style="display:none" title="Obrir/tancar barra d'eines" type="button">
# 							<span class="rsicn rsicn-arrow-down"></span><span class="rsbtn_btnlabel" style="width: 0px; height: 0px;">Obrir/tancar barra d'eines</span>
# 						</button>
# 					</div>
# 				</div>
# 		</div>
# </div>
# 	      </div>
#
#       <div class="row-fluid" id="content-zone" style="float:left;">
#         <div class="span6 hasTitleContent menuleft" id="tocify">
#
#               <div class="uib_style_accessosdir">
# 		<h2 class="uib_style_color_">
# 				Accedeix als grups</h2>
# 		<ul class="uib_accessos_directes">
# 			<li>
# 							<a href="/recerca/estructures/grups/grups_area/" target="_self">
# 								Llista de grups</a>
# 						</li>
# 			<li>
# 							<a href="/recerca/estructures/grups/cerca_grups/" target="_self">
# 								Cerca de grups</a>
# 						</li>
# 			<li>
# 							<a href="/recerca/estructures/grups/cerca_produccio/" target="_self">
# 								Producció científica</a>
# 						</li>
# 			</ul>
#
# 		</div><div class="uib_style_accessosdir">
# 		<h2 class="uib_style_color_">
# 				Gestió dels grups</h2>
# 		<ul class="uib_accessos_directes">
# 			<li>
# 							<a href="https://osr.uib.es/forme/grupsderecerca.php" target="_blank" title="Obri una nova finestra">
# 								Formulari d'alta, baixa i modificació de grups</a>
# 						</li>
# 			<li>
# 							<a href="http://www.uib.cat/recerca/ajuts/doc/grupsderecerca/normativa_grups_recerca_2016.pdf" target="_blank" title="Obri una nova finestra">
# 								Normativa de grups de recerca</a>
# 						</li>
# 			<li>
# 							<a href="/recerca/estructures/grups/info/" target="_self">
# 								Com mantenir el web del vostre grup</a>
# 						</li>
# 			</ul>
#
# 		</div><div class="uib_style_accessosdir">
# 		<h2 class="uib_style_color_">
# 				Suport a la recerca</h2>
# 		<ul class="uib_accessos_directes">
# 			<li>
# 							<a href="/lauib/Govern-i-organitzacio/Organs-de-govern/Vicerectors/vr.investigacio/" target="_self">
# 								Vicerectorat d'Investigació i Internacionalització</a>
# 						</li>
# 			<li>
# 							<a href="http://osr.uib.cat" target="_self">
# 								Oficina de Suport a la Recerca (OSR)</a>
# 						</li>
# 			<li>
# 							<a href="https://webgrec.uib.es" target="_self">
# 								GREC a la UIB</a>
# 						</li>
# 			<li>
# 							<a href="https://ppi.uib.cat" target="_self">
# 								Portal del Personal Investigador (PPI)</a>
# 						</li>
# 			<li>
# 							<a href="http://sct.uib.cat" target="_self">
# 								Serveis Cientificotècnics</a>
# 						</li>
# 			<li>
# 							<a href="http://uni-g9.net/catalogo-tecnicas" target="_self">
# 								Catàleg de Serveis de Suport a la Recerca del G-9</a>
# 						</li>
# 			</ul>
#
# 		</div>
#
#               <div class="hiddenzone"> </div>
#
#            </div>
#
#            <div class="span14" id="uib_grid_content" lang="ca" role="main">
# 	          <div class="row-fluid">
# 		            <h1 class="titlePage" id="titleContent" itemprop="alternateName">Llista de grups de recerca segons àrea AEI</h1>
# 		                </div>
# 		      <div class="row-fluid">
# 	             <div class="titled_box layout1" id="uib_style_content" itemprop="mainContentOfPage">
#
# 								<div class="uib_style_filaunica"><div>
# <link href="https://www.uib.cat/recerca/estructures/grups/css/estils.css" rel="stylesheet" type="text/css"/>
#
# <noscript class="uib_error">Per veure aquesta pàgina de manera totalment correcta heu de tenir Javascript activat. Configurau el vostre navegador.<br/>
# <br/>
# </noscript>
# <form action="/portletbridge/pbhs/cKZXU3o95kaWiAL61/grups_area.php;jsessionid=9BEC2C438BA752A0B2BC2A6A1C87DD73.infogluelive1" id="form_main" method="get">
#   <script type="text/javascript" xmlns="http://www.w3.org/1999/xhtml">
#       function fes_seleccio(){
#            var form=document.getElementById("form_main");
#
#            location.href="https://www.uib.cat/recerca/estructures/grups/grups_area/id_area="+form.id_area.value;
#            return false;
#     }
#   <!--// No collapsing allowed--></script>
#
# <fieldset>
#
# <legend class="et_oculta">Llista de grups de recerca segons àrea AEI</legend>
#   	<label for="id_area">Selecciona Àrea AEI:</label>
#     <select id="id_area" name="id_area" onchange="fes_seleccio(); return false;">
#         <option selected="" value="-1">Totes </option>
#         <option value="18">Biociències i Biotecnologia (BIO)</option><option value="19">Biomedicina (BME)</option><option value="17">Ciències Agràries i Agroalimentàries (CAA)</option><option value="7">Ciències de l'Educació (EDU)</option><option value="10">Ciències Físiques (FIS)</option><option value="15">Ciències i Tecnologies de Materials (MAT)</option><option value="16">Ciències i Tecnologies Mediambientals (CTM)</option><option value="14">Ciències i Tecnologies Químiques (CTQ)</option><option value="9">Ciències Matemàtiques (MTM)</option><option value="1">Ciències Socials (CSO)</option><option value="5">Cultura: Filologia, Literatura i Art (FLA)</option><option value="2">Dret (DER)</option><option value="3">Economia (ECO)</option><option value="6">Estudis del Passat: Historia i Arqueologia (PHA)</option><option value="4">Ment, Llenguatge i Pensament (MLP)</option><option value="11">Producció industrial, enginyeria civil i enginyeries per a la societat (PIN)</option><option value="8">Psicologia (PSI)</option><option value="12">Tecnologies de la Informació i de les Comunicacions (TIC)</option>    </select>
# <br/>
#
# </fieldset>
#
# </form>
#
# <h2>Biociències i Biotecnologia (BIO)</h2>
#
# <ul>
# <li>
# <a href="https://www.uib.cat/recerca/estructures/grups/grup/GENEHUMA/">Genètica humana</a>
# </li>
# <li>
# <a href="https://www.uib.cat/recerca/estructures/grups/grup/Microbio/">Microbiologia (Microbio)</a>
# </li>
# </ul>
# <h2>Biomedicina (BME)</h2>
#
# <ul>
# <li>
# <a href="https://www.uib.cat/recerca/estructures/grups/grup/BIOCANCER/">Biologia Cel·lular del Càncer (BIOCANCER)</a>
# </li>
# <li>
# <a href="https://www.uib.cat/recerca/estructures/grups/grup/MOLONE/">Biologia molecular i salut global</a>
# </li>
# <li>
# <a href="https://www.uib.cat/recerca/estructures/grups/grup/CurES/">Cures, cronicitat i evidències en salut (CurES)</a>
# </li>
# <li>
# <a href="https://www.uib.cat/recerca/estructures/grups/grup/EVES/">Evidència, Estils de Vida i Salut</a>
# </li>
# <li>
# <a href="https://www.uib.cat/recerca/estructures/grups/grup/GMOT/">Grup Multidisciplinar d'Oncologia Translacional (GMOT)</a>
# </li>
# <li>
# <a href="https://www.uib.cat/recerca/estructures/grups/grup/INFEINMU/">Infecció i immunitat</a>
# </li>
# <li>
# <a href="https://www.uib.cat/recerca/estructures/grups/grup/ONCOHEMA/">Investigació clínica i traslacional</a>
# </li>
# <li>
# <a href="https://www.uib.cat/recerca/estructures/grups/grup/LITIRENA/">Litiasi renal i patologies relacionades</a>
# </li>
# </ul>
# <div class="paginacio">Pàg. <strong>[1]</strong> <a href="https://www.uib.cat/recerca/estructures/grups/grups_area/npag=2">[2]</a> <a href="https://www.uib.cat/recerca/estructures/grups/grups_area/npag=3">[3]</a> <a href="https://www.uib.cat/recerca/estructures/grups/grups_area/npag=4">[4]</a> <a href="https://www.uib.cat/recerca/estructures/grups/grups_area/npag=5">[5]</a> <a href="https://www.uib.cat/recerca/estructures/grups/grups_area/npag=6">[6]</a> <a href="https://www.uib.cat/recerca/estructures/grups/grups_area/npag=7">[7]</a> <a href="https://www.uib.cat/recerca/estructures/grups/grups_area/npag=8">[8]</a> ... <a href="https://www.uib.cat/recerca/estructures/grups/grups_area/npag=15">[15]</a>  <a href="https://www.uib.cat/recerca/estructures/grups/grups_area/npag=2"><img alt="Icona dreta" src="https://www.uib.cat/recerca/estructures/grups/img/icofletxaorddreta.gif" title="Pàg. Següent"/></a>
# <br/>
# <form action="/portletbridge/pbhs/cKZXU3o95kaWiAL61/grups_area.php;jsessionid=9BEC2C438BA752A0B2BC2A6A1C87DD73.infogluelive1" id="form_pag" onsubmit="anar_a(); return false;">
# 						  <script src="https://www.uib.cat/recerca/estructures/grups/js/chkform.js" type="text/javascript" xmlns="http://www.w3.org/1999/xhtml"><!--// No collapsing allowed--></script>
# 						  <script type="text/javascript" xmlns="http://www.w3.org/1999/xhtml">
# 						  // <!--
# 						  function anar_a(){
# 							var num_pag=document.getElementById("npag").value;
#
# 							if(isInteger(num_pag) && num_pag<=15 && num_pag>=1){
# 								location.href="https://www.uib.cat/recerca/estructures/grups/grups_area/npag="+num_pag;
# 							}
# 							return false;
# 						  }
# 						  // -->
# 						  <!--// No collapsing allowed--></script>
#
# <input type="submit" value="Anar a"/> <input id="npag" name="npag" size="3" type="text"/>
#
# </form>Grup(s) 1-10 de 147
# 		</div>
#
# <script type="text/javascript">//onloadcode
#             </script>
# </div>
# </div>
#
#
#
#
# 					</div></div></div></div></div><footer class="row-fluid" id="peu">
#
#  	<div class="footernews row-fluid">
# 	<div class="row row-cols-md-4 noticiesCards align-items-stretch">
# 		<div class="col-sm-6 col-md">
# 			<article class="card zEH">
# 						<a href="https://setmanadelpostgrau.uib.cat/?utm_source=Web&amp;utm_medium=Cubo&amp;utm_campaign=SetmanaPostgrau21" title="VI Setmana del Postgrau">
# 							<div class="data">
# 									<figure>
# 										<img alt="VI Setmana del Postgrau" src="/digitalAssets/629/thumbnail_350_350_629240_RECT_cubo1-cat-setmanapostgrau2021.jpg"/>
# 									</figure>
# 									</div>
# 						</a>
# 				</article>
# 			</div>
# 		<div class="col-sm-6 col-md">
# 			<article class="card zEH">
# 						<a href="https://campusdigital.uib.cat/Factoria/jornades_2021/?utm_source=Web&amp;utm_medium=AraInteressa&amp;utm_campaign=JornadesDocents21" title="III Jornades d'Experiències Docents 2021">
# 							<div class="data">
# 									<figure>
# 										<img alt="III Jornades d'Experiències Docents 2021" src="/digitalAssets/627/thumbnail_350_350_627449_RECT_cubo-portal-pdi_cat_iii-jornades-docents.jpg.png"/>
# 									</figure>
# 									</div>
# 						</a>
# 				</article>
# 			</div>
# 		<div class="col-sm-6 col-md">
# 			<article class="card zEH">
# 						<a href="https://seras.uib.cat/" title="Seràs UIB">
# 							<div class="data">
# 									<figure>
# 											<img alt="Seràs UIB" src="/digitalAssets/614/thumbnail_350_350_614357_RECT_cubos_subapartats_2020_seras-uib__cat.jpg.png"/>
# 									</figure>
# 									</div>
# 						</a>
# 				</article>
# 			</div>
# 		<div class="col-sm-6 col-md">
# 			<article class="card">
# 			<!---->
# 		<div id="uib_actualitat_widget">
#  	<h2>Diari UIB</h2>
#  	<span>
#  		<a href="https://diari.uib.cat/Hemeroteca/Convocades-les-eleccions-a-Rector-de-la-UIB-per-al.cid665216">Convocades les eleccions a Rector de la UIB per al dia 20 de maig de 2021</a>
# 		</span>
# 	<span><a class="linkmes" href="https://diari.uib.cat/Hemeroteca/">
# 			Més notícies</a></span>
# 	</div>
#
# </article>
# 		</div>
# 	</div>
# </div>
#
# <div class="span20" id="uib_grid_footer">
# 	<div class="row-fluid hidden-print" id="uib_footerLinks">
# 		<div class="span10">
#
# 			<ul id="linksnormativa">
# 			<li>
# 					<a href="/Accessibilitat/" target="_self">Accessibilitat</a>
# 					</li>
# 				<li>
# 					<span> | </span><a href="/Avis-legal/" target="_self">Avís legal</a>
# 					</li>
# 				</ul>
#
#
# 		</div>
# 		<div class="span10 text-right">
# 			 	<ul class="links">
# 			 		<li>
# 			 			<a href="/Contacta-amb-la-UIB.cid315174?x_ig_aplicacio=contacte" id="f_contacte" title="Contacte">Contacte</a>
# 				 		</li>
# 			 		<li>
# 			 			<a href="https://informacio.uib.cat/" id="f_informacio" title="Informació">Informació</a>
# 			 		</li>
# 			 		<li>
# 			 			<a href="https://estudis.uib.cat/Preguntes-frequents/" id="f_faqs" title="Preguntes freqüents">Preguntes freqüents</a>
# 			 		</li>
# 		 		</ul>
# 		</div>
#
# 		</div>
# 	<div class="row-fluid" id="uib_grid_footer_withoutbox">
#
# 		©2021 Universitat de les Illes Balears. Cra. de Valldemossa, km 7.5. Palma (Illes Balears). Tel.: (+34) 971 17 30 00. E-07122. CIF: Q0718001A</div>
# </div>
#
# </footer>
#   </div><!-- The social media icon bar -->
# <div class="social-icon-bar">
#   <a class="facebook" href="https://www.facebook.com/UniversitatUIB/"><span class="fab fa-facebook-f"></span><span>Facebook de la UIB</span></a>
#   <a class="twitter" href="https://twitter.com/UIBuniversitat"><span class="fab fa-twitter"></span><span>Twitter de la UIB</span></a>
#   <a class="linkedin" href="https://www.linkedin.com/edu/school?id=12254"><span class="fab fa-linkedin"></span><span>Linkedin de la UIB</span></a>
#   <a class="instagram" href="https://www.instagram.com/uibuniversitat/"><span class="fab fa-instagram"></span><span>Instagram de la UIB</span></a>
#   <a class="youtube" href="https://www.youtube.com/user/UIBuniversitat"><span class="fab fa-youtube"></span><span>Youtube de la UIB</span></a>
#   <a class="spotify" href="https://open.spotify.com/show/5EHem6fubSB8xVm9VX8ObU?si=Xr9lm24jSSyJgid-uCTvog"><span class="fab fa-spotify"></span><span>Spotify de la UIB</span></a>
#
# </div>
#
# <a class="uib_hidden" href="https://plus.google.com/110271182304237658146/" rel="publisher">Google+ UIB</a>
#   <meta content="2021-04-22 10:44" itemprop="dateModified"/>
#   <script type="text/javascript">
# 	    $(function() {
# 	      scrollTopButton("Puja","Tanca");
#
# 	    });
# 		</script>
#   <script>
# 	(function(h,e,a,t,m,p) { m=e.createElement(a);m.async=!0;m.src=t;
# 	p=e.getElementsByTagName(a)[0];p.parentNode.insertBefore(m,p);
# 	})(window,document,'script','https://u.heatmap.it/log.js');
#   </script>
#
#   <link href="/digitalAssets/extensions/615738-cssdircom/readspeaker.css" rel="stylesheet" type="text/css"/>
#
# <script src="/digitalAssets/extensions/615738-jquery/jquery.utils.uib-min.js?version=20201019.js" type="text/javascript"></script>
# <script src="/digitalAssets/extensions/615738-jquery/jquery.sticky-kit.min.js" type="text/javascript"></script>
# <script src="/digitalAssets/extensions/615738-cssdircom/js/html5shiv_ie9.js" type="text/javascript"></script>
# <link href="/digitalAssets/extensions/615738-cssdircom/dircom_printer.css" media="print" rel="stylesheet" type="text/css"/>
# <script src="//cdn1.readspeaker.com/script/9829/webReader/webReader.js?pids=wr&amp;dload=DocReader.AutoAdd&amp;disable=readhover" type="text/javascript"></script>
# <style>
# .rs_addtools a, .rs_addtools span, .rsbtn a, .rsbtn span{color:white;}
# .rsbtn_tools .rsicn,
# .rsbtn_tools .rsbtn span,
# .rsbtn_tools .rsbtn_btnlabel,
# .rsbtn .rsbtn_toolpanel .rsbtn_tools .rsbtn_tools_inner .rsbtn_toolcontainer .rsbtn_btnlabel {color:black;display:inline-block;}
# .rsbtn .rsbtn_exp .rsbtn_exp_inner .rsbtn_stop span.rsicn,
# .rsbtn .rsbtn_exp .rsbtn_exp_inner .rsbtn_pause span.rsicn{color:white;}
# </style>
# <script src="/digitalAssets/extensions/615738-jquery/jquery.readspeaker-min.js" type="text/javascript"></script>
#
#
#
#
#
# </body></html>

# %% [markdown]
# Podemos ver que las categorias se encuentran en un elemento *div* con clase *uib_style_filaunica*

# %%
contenedor = categorias.find("div", class_="uib_style_filaunica")

# %% [markdown]
# En este elemento, se organizan como *li*

# %%
grupos = contenedor.find_all("li")

# %%
grupos
# Out:
# [<li>
#  <a href="https://www.uib.cat/recerca/estructures/grups/grup/GENEHUMA/">Genètica humana</a>
#  </li>,
#  <li>
#  <a href="https://www.uib.cat/recerca/estructures/grups/grup/Microbio/">Microbiologia (Microbio)</a>
#  </li>,
#  <li>
#  <a href="https://www.uib.cat/recerca/estructures/grups/grup/BIOCANCER/">Biologia Cel·lular del Càncer (BIOCANCER)</a>
#  </li>,
#  <li>
#  <a href="https://www.uib.cat/recerca/estructures/grups/grup/MOLONE/">Biologia molecular i salut global</a>
#  </li>,
#  <li>
#  <a href="https://www.uib.cat/recerca/estructures/grups/grup/CurES/">Cures, cronicitat i evidències en salut (CurES)</a>
#  </li>,
#  <li>
#  <a href="https://www.uib.cat/recerca/estructures/grups/grup/EVES/">Evidència, Estils de Vida i Salut</a>
#  </li>,
#  <li>
#  <a href="https://www.uib.cat/recerca/estructures/grups/grup/GMOT/">Grup Multidisciplinar d'Oncologia Translacional (GMOT)</a>
#  </li>,
#  <li>
#  <a href="https://www.uib.cat/recerca/estructures/grups/grup/INFEINMU/">Infecció i immunitat</a>
#  </li>,
#  <li>
#  <a href="https://www.uib.cat/recerca/estructures/grups/grup/ONCOHEMA/">Investigació clínica i traslacional</a>
#  </li>,
#  <li>
#  <a href="https://www.uib.cat/recerca/estructures/grups/grup/LITIRENA/">Litiasi renal i patologies relacionades</a>
#  </li>]

# %% [markdown]
# Cada unos de los grupos tiene un enlace. Por ejemplo el primer enlace que podemos ver es el siguiente

# %%
grupos[0].find("a").get("href")
# Out:
# 'https://www.uib.cat/recerca/estructures/grups/grup/GENEHUMA/'

# %% [markdown]
# Añadimos la función creada en clase para extraer el grupo

# %%
def extrae_grupo(item):
    nombre = item.text.strip()
    url = item.find("a").get("href")
    return nombre, url

# %% [markdown]
# También añadimos una función que nos indica si hay una siguiente página con más grupos.

# %%
def hay_siguiente(pagina):
    return pagina.find("img", title="Pàg. Següent") is not None

# %% [markdown]
# Una vez tenemos la url donde se encuentra la información del grupo de investigación, tenemos que encontrar donde está el equipo de investigación para obtener lo que se nos pide. Añadiendo "/equip/index.html" a la url obtenida anteriormente podemos entrar a la información del grupo de investigación, pero esto no ocurre con todas las páginas ya que tenemos varias excepciones.
#
# Estas excepciones son las siguientes:
#
# * "https://engalim.uib.cat/Grupo-investigador/"
#
# * "https://gicafe.uib.cat/Estructura_I_Personal/"
#
# * "https://eic.uib.cat/Equip-investigador/"
#
# * "https://gedhe.uib.cat/Equip-investigador/"
#
# * "https://gifes.uib.cat/Research-staff/"
#
# * "https://meteo.uib.cat/equip/"
#
# * "https://recumare.uib.cat/EquipInvestigador/"
#
# * "https://reacmole.uib.cat/Equip-investigador/"
#
# * "https://ccts.uib.cat/Equipo-investigador/"
#
# * "https://desigualtats.uib.cat/Equip-investigador/"
#
# * "https://gresib.uib.cat/Equip-investigador/"
#
# * "https://relatmit.uib.cat/Equip-investigador/"
#
# * "https://grupestudidha.uib.cat/Equip-investigador/"
#
# * "https://praxis.uib.cat/Equip/"
#
# * "https://imasdel.uib.cat/Equip/"
#
# * "https://ndpc.uib.cat/Equip-investigador/"
#
# * "https://acsic.uib.cat/EquipInv/"
#
# * "https://scopia.uib.cat/Equip/"
#
# Guardaremos en una lista todas estas excepciones.

# %%
lista_excepciones = ["https://engalim.uib.cat/Grupo-investigador/","https://gicafe.uib.cat/Estructura_I_Personal/",
                       "https://eic.uib.cat/Equip-investigador/", "https://gedhe.uib.cat/Equip-investigador/",
                       "https://gifes.uib.cat/Research-staff/","https://meteo.uib.cat/equip/",
                       "https://recumare.uib.cat/EquipInvestigador/", "https://reacmole.uib.cat/Equip-investigador/",
                       "https://ccts.uib.cat/Equipo-investigador/", "https://desigualtats.uib.cat/Equip-investigador/",
                       "https://gresib.uib.cat/Equip-investigador/", "https://relatmit.uib.cat/Equip-investigador/",
                       "https://grupestudidha.uib.cat/Equip-investigador/", "https://praxis.uib.cat/Equip/",
                       "https://imasdel.uib.cat/Equip/", "https://ndpc.uib.cat/Equip-investigador/",
                       "https://acsic.uib.cat/EquipInv/", "https://scopia.uib.cat/Equip/"]

# %% [markdown]
# Accedemos a la página de los investigadores de la que hemos tomado de ejemplo.

# %%
pgrupo_url = grupos[0].find("a").get("href") + "/equip/index.html"

# %%
pgrupo = load_page(pgrupo_url)

# %% [markdown]
# La información que nos interesa se encuentra dentro de un elemento *div* con atributo *itemprop* y con valor *mainContentOfPage*

# %%
contenido = pgrupo.find("div", itemprop="mainContentOfPage")

# %%
lista_rel = contenido.find_all("h3")

# %%
lista_rel
# Out:
# [<h3>Investigadora principal</h3>, <h3>Membres</h3>, <h3>Col·laboradors</h3>]

# %% [markdown]
# Las personas que se encuentran en cada rango dentro del grupo de investigación son las siguientes a cada elemento de la lista anterior.

# %%
personal = lista_rel[2].find_next_sibling().find_all("li")

# %%
personal
# Out:
# [<li><a class="link_fitxa" href="https://www.uib.cat/personal/ABjIwNDQxMw/">Dr. José Antonio Jurado Rivera</a> (Professor contractat doctor interí)</li>,
#  <li><a class="link_fitxa" href="https://www.uib.cat/personal/ABjIwNDE4NA/">Dra. Joana Francesca Ferragut Simonet</a> (Professora ajudanta doctora)</li>,
#  <li>Dra. Maria Magdalena Parera Rossello (Professora associada)</li>,
#  <li><a class="link_fitxa" href="https://www.uib.cat/personal/ABjIyMTkwNA/">Sra. Iris Alemany Hermoso</a> (CAIB -&gt; Contractada predoctoral)</li>,
#  <li><a class="link_fitxa" href="https://www.uib.cat/personal/ABjIwNDA3MQ/">Sra. Joana Maria Buades Payeras</a> (CAIB -&gt; Contractada predoctoral)</li>,
#  <li><a class="link_fitxa" href="https://www.uib.cat/personal/ABTIxNzM3/">Sra. Virginia Rodríguez Delgado</a> (CAIB -&gt; Contractada predoctoral)</li>,
#  <li>Sra. Beatriz Sánchez Barceló (Professora associada)</li>]

# %% [markdown]
# Ahora realizaremos un estudio de cada individuo en el grupo de investigación que hemos elegido de prueba. Lo primero será sacar el nombre del investigador. Lo haremos de ejemplo para la tercera persona.

# %%
persona = personal[2].text

# %%
partes = persona.split('(')

# %%
p1 = partes[0].strip().split()

# %%
p1
# Out:
# ['Dra.', 'Maria', 'Magdalena', 'Parera', 'Rossello']

# %% [markdown]
# Agrupamos el nombre

# %%
nombre = " ".join(p1[1:])

# %%
nombre
# Out:
# 'Maria Magdalena Parera Rossello'

# %% [markdown]
# El primer elemento de la lista nos puede servir para determinar el género del individuo. Utilizaremos la función siguiente que vimos en clase.

# %%
def genero(p):
    if p[2]=='a':
        return "FEMENINO"
    else:
        return "MASCULINO"

# %%
genero(p1[0])
# Out:
# 'FEMENINO'

# %% [markdown]
# La otra sección que tenemos en la variable **partes** nos indica el vínculo que el individuo tiene con la universidad.

# %%
partes[1][:-1]
# Out:
# 'Professora associada'

# %% [markdown]
# Por último, hemos de obtener el Curriculum Vitae de cada investigador. Ya que puede ser que haya CV que estén en un idioma y no en otro, lo que haremos será leer los CV de los 3 idiomas. En el ejemplo leeremos solo el CV en catalán.
#
# Lo primero que hemos de hacer es tomar la página donde se encuentra la información del investigador. En nuestro ejemplo sería la siguiente

# %%
url = personal[0].find("a").get('href')

# %% [markdown]
# Cargamos la página y utilizamos la siguiente función vista en clase (con unas modificaciones) para obtener el CV. En el caso de que no exista CV, se puede encontrar un elemento *div* de clase *uib_style_nolanguageversion*.

# %%
pagina_cv = load_page(url)

# %%
def extrae_cv(url):
    pagina_cv = load_page(url)
    if pagina_cv.find("div", class_ = "uib_style_nolanguageversion") is not None:
        return "No existe CV en este idioma"
    else:
        if pagina_cv.find("div", id = "cv_breve") is not None:
            return pagina_cv.find("div", id = "cv_breve").text
        else:
            return "No tiene CV en este idioma"

# %% [markdown]
# En el ejemplo que estamos tratando, obtenemos el siguiente CV

# %%
extrae_cv(url)
# Out:
# "Llicenciat en Biologia per la Universidad de Granada (2002) i Doctor en Biologia per la UIB (2015). Ha realitzat estades de recerca a British Natural History Museum (London, UK), Australian Museum (Sydney, Australia), Western Australian Museum (Perth, Australia), Reserva Biológica Alberto Manuel Brenes (Costa Rica), Institut de Biologia Evolutiva (CSIC, Barcelona), Institut Agronomique Neo-Caledonien (Nova Caledònia) finançat pel Govern Espanyol, per la UE, i per la National Geographic Society. Des de 2009 a 2014 va estar vinculat amb contractes de recerca a l'Institut Mediterrani d'Estudis Avançats (IMEDEA, CSIC). Durant 5 anys va ser Professor Associat del Departament de Biologia (Genètica) de la UIB (2010-2014). Va posteriorment obtenir un contracte com a Professor Ajudant Doctor a la mateixa institució (2015). Durant l'etapa doctoral va treballar en l'estudi molecular basat en seqüències d'ADN de les relacions evolutives i la història biogeogràfica d'artròpodes. A més, va desenvolupar un estudi pioner dirigit a la caracterització molecular de les interaccions tròfiques en sistemes d'insectes herbívors. Ha estat investigador de 8 projectes de recerca. Temes d'interès: Biologia Evolutiva, Sistemàtica Molecular, Biogeografia, Evolució Molecular. Llista de publicacions científiques a ResearchID: http://www.researcherid.com/rid/H-2497-2015"

# %% [markdown]
# Aplicando todos estos pasos a cada grupo de investigación, obtendríamos lo que buscamos.
#
# Utilizaremos la siguiente función para extraer los datos de cada investigador y guardarlos como un diccionario.

# %%
def extrae_investigador(item,tipo, idioma, grupo):
    if item.find("a", class_="link_fitxa") is not None:
        url = item.find("a").get('href')
    else:
        url = None
    texto = item.text
    partes = texto.split("(")
    p1= partes[0].strip().split()
    nombre = " ".join(p1[1:])
    gener = genero(p1[0])
    if tipo.text[2]== 'v': # De esta forma agrupamos en una etiqueta a todos los investigadores principales.
        tipo_investigador = "Investigador/a principal"
    else:
        tipo_investigador = tipo.text
    titulo = p1[0]
    if len(partes)>1: # Añadimos este if porque hay individuos en los que no aparece su relación con la UIB.
        relacion_uib = partes[1][:-1]
    else:
        relacion_uib = "No tiene"
    cv=[]
    if url is not None: # Extraer el CV en catalan
        cv.append(extrae_cv(url))
    else:
        cv.append("No tiene CV en este idioma")
    for i in (0,1): # Extraer el CV en Castellano e Ingles.
        if url is not None:
            url = url.replace(idioma[i], idioma[i+1])
            cv.append(extrae_cv(url))
        else:
            cv.append("No tiene CV en este idioma")
    dicc = {"Grupo": grupo, "Nombre": nombre, "Genero": gener,
                    "Tipo de investigador": tipo_investigador,  "Titulo" : titulo,
                    "Relacion UIB": relacion_uib, "CV_cat": cv[0], "CV_esp": cv[1], "CV_eng": cv[2]}
    return dicc

# %% [markdown]
# La función está basada en la que se hizo en clase pero con pequeñas modificaciones que se han necesitado por los siguientes motivos:
#
# * Investigadores que no tiene pagína donde encontrar sus datos
#
# * Investigadores en los que no aparece su vínculo con la UIB

# %% [markdown]
# Utilizaremos la siguiente función (que ya empleamos para extraer los chistes) para recopilar los datos de las diferentes páginas de grupos de investigación.

# %%
def parse_pages():
    pagina = 1
    while parse_page(pagina):
        time.sleep(random.randrange(1, 3))
        pagina = pagina + 1

# %% [markdown]
# Definimos la siguiente función para recorrer y recoger los datos de todas la páginas

# %%
def parse_page(pagina):
    print("parsing page ", pagina)
    categorias = load_page(url_categorias.format(pagina))
    time.sleep(random.randrange(1, 3))
    contenedor = categorias.find("div", class_="uib_style_filaunica")
    grupos = contenedor.find_all("li")
    for c in grupos:
        a = extrae_grupo(c)
        pgrupo_url = a[1] + "/equip/index.html"
        idiomas = [".cat", ".es/es", ".eu"] # Para leer los cv de todos los idiomas
        pgrupo = load_page(pgrupo_url)
        time.sleep(random.randrange(1, 3))
        if pgrupo is None: # Esta condición sirve para poder leer las paginas que no siguen lo habitual.
            nueva_pagina = lista_excepciones[0]
            idiomas = [".cat", ".es", ".eu"] # Si cambia la pagina hay que cambiar tambien la forma de las extensiones
            pgrupo = load_page(nueva_pagina)
            lista_excepciones.pop(0)
        contenido = pgrupo.find("div", itemprop="mainContentOfPage")
        lista_rel = contenido.find_all("h3")
        for i in lista_rel:
            time.sleep(random.randrange(1, 4))
            personal = i.find_next_sibling().find_all("li")
            for j in personal:
                investigador = extrae_investigador(j,i, idiomas,a[0])
                datos.append(investigador)
    return hay_siguiente(categorias)

# %% [markdown]
# Comenzamos a crear el diccionario

# %%
datos = []
parse_pages()
# Out:
# parsing page  1
# parsing page  2
# Esta página no existe. Cambiamos a una de la lista
# parsing page  3
# Esta página no existe. Cambiamos a una de la lista
# Esta página no existe. Cambiamos a una de la lista
# Esta página no existe. Cambiamos a una de la lista
# Esta página no existe. Cambiamos a una de la lista
# parsing page  4
# parsing page  5
# Esta página no existe. Cambiamos a una de la lista
# parsing page  6
# Esta página no existe. Cambiamos a una de la lista
# Esta página no existe. Cambiamos a una de la lista
# parsing page  7
# Esta página no existe. Cambiamos a una de la lista
# Esta página no existe. Cambiamos a una de la lista
# Esta página no existe. Cambiamos a una de la lista
# parsing page  8
# Esta página no existe. Cambiamos a una de la lista
# parsing page  9
# parsing page  10
# parsing page  11
# Esta página no existe. Cambiamos a una de la lista
# parsing page  12
# Esta página no existe. Cambiamos a una de la lista
# parsing page  13
# parsing page  14
# Esta página no existe. Cambiamos a una de la lista
# Esta página no existe. Cambiamos a una de la lista
# Esta página no existe. Cambiamos a una de la lista
# parsing page  15
# Esta página no existe. Cambiamos a una de la lista

# %% [markdown]
# Veamos lo que hemos obtenido

# %%
datos
# Out:
# [{'Grupo': 'Genètica humana',
#   'Nombre': 'Cori Ramon Juanpere',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Investigador/a principal',
#   'Titulo': 'Dra.',
#   'Relacion UIB': "Catedràtica d'universitat",
#   'CV_cat': 'Llicenciada en Ciencies per la UAB i doctora en Ciencies per la UIB. Catedràtica de Genètica a la UIB. Ha impartit docencia de materies de Genètica i Evolució, a llicenciatura Grau i Posgrau/Doctorat. La recerca està centrada en la Genètica poblacional i evolutiva amb especial enfasis a la diferenciació en els entorns insulars.',
#   'CV_esp': 'No existe CV en este idioma',
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Genètica humana',
#   'Nombre': 'José Aurelio Castro Ocón',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Dr.',
#   'Relacion UIB': "Catedràtic d'universitat",
#   'CV_cat': "El camp general d'investigació que he desenvolupat en els darrers anys està relacionat amb la Genètica de Poblacions i l'Evolució, tant de poblacions humanes (sobretot la població humana de l'arxipèlag balear), malalties genètiques (hemocromatosi hereditària, porfíria variegata, beta-talassèmia, malaltia de Crohn); com d'organismes com Drosophila (dinàmica poblacional dels haplotips del DNA mitocondrial en Drosophila subobscura); virus (dinàmica poblacional dels virus de RNA, sobretot el de l'hepatitis C, en pacients coinfectats amb VHC-VIH); paràsits de mol·luscs (gèneres Martelia i Perkinsus) o sargantanes (filogeografia de Podarcis lilfordi i Podarcis pityusensis, sargantanes endèmiques de les Illes Balears, entre d'altres). Actualment també participo en investigacions relacionades amb la dinàmica poblacional i evolució de la microbiota intestinal d'animals i humans.",
#   'CV_esp': 'El campo general de investigación que he desarrollado en los últimos años está relacionado con la Genética de Poblaciones y la Evolución, tanto de poblaciones humanas (sobre todo la población humana del archipiélago balear), enfermedades genéticas (hemocromatosis hereditaria, porfiria variegata, beta-talasemia, enfermedad de Crohn); como de organismos tales como Drosophila (dinámica poblacional de los haplotipos del DNA mitocondrial en Drosophila subobscura); virus (dinámica poblacional de los virus de RNA, sobre todo el de la hepatitis C, en pacientes coinfectados con VHC-VIH); parásitos de moluscos (géneros Martelia y Perkinsus) o lagartijas (filogeografia de Podarcis lilfordi y Podarcis pityusensis, lagartijas endémicas de les Illes Balears, entre otras). Actualmente también participo en investigaciones relacionadas con la dinámica poblacional y evolución de la microbiota intestinal de animales y humanos.',
#   'CV_eng': 'The general field of research that I have developed in recent years is related to population genetics and evolution, as human populations (especially the human population of the Balearic Islands), genetic diseases (hereditary hemochromatosis, porphyria variegata, beta-thalassemia, Crohn disease); or organisms such as Drosophila (population dynamics of mitochondrial DNA haplotypes in Drosophila subobscura); virus (population dynamics of RNA viruses, particularly hepatitis C in patients coinfected with HCV-HIV); mollusc parasites (genera Martelia and Perkinsus) or lizards (phylogeography of Podarcis lilfordi and Podarcis pityusensis, Balearic endemic lizards, among others).Currently, I also participate in research related to population dynamics and evolution of the intestinal microbiota of animals and humans.'},
#  {'Grupo': 'Genètica humana',
#   'Nombre': 'Antonia Picornell Rigo',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Dra.',
#   'Relacion UIB': "Catedràtica d'universitat",
#   'CV_cat': "Llicenciada en Ciències (Biologia) (Premi Extraordinari, 1998) i Doctora en Biologia (1992) per la Universitat de les Illes Balears. Vaig iniciar la carrera docent com Ajudant a la UIB el novembre de 1993 i desprès d'ocupar diverses places, sóc Catedràtica d'Universitat de Genètica en el Departament de Biologia de la UIB des de juliol de 2017. He impartit docència als estudis de Biologia i Bioquímica, especialment en les matèries de Enginyeria Genètica, Genètica Humana i Genètica Molecular. La meva activitat investigadora s'ha desenvolupat dins el camp de la Genètica de poblacions (en especial interès en les poblacions insulars). Les línies dins d'aquest camp han estat diverses, d'una banda s'ha estudiat la població balear des d'un punt de vista genètic-poblacional, tant a nivell antropològic com a nivell d'algunes malalties genètiques (hemocromatosi hereditària, porfíria variegata, beta-talassèmia), i també poblacions jueves de diversos orígens. D'altra banda, va ser objecte d'estudi la dinàmica poblacional de l'ADN mitocondrial en Drosophila subobscura. Finalment, en els darrers anys, hem treballat en l'estudi multidisciplinari de l'evolució del gènere Podarcis a la Mediterrània. Fruit de les diferents línies de treball descrites, he publicat 65 articles en revistes indexades internacionals i he estat investigadora en 16 projectes nacionals i 24 autonòmics, dels quals he estat investigador responsable en 6. He fet estades a les universitats de Haifa, Munic, Salta, Barcelona, Porto i a l'Hospital Beth Israel de Nova York. He ocupa't diversos càrrecs acadèmics i de gestió a la UIB: Co-directora del Màster en Biotecnologia, Genètica i Biologia Cel·lular durant 4 cursos; Membre en la comissió d'elaboració i disseny (CED) del Grau de Bioquímica, i de la CED dels Màsters en Biotecnologia, Genètica i Biologia Cel·lular i en Biotecnologia Aplicada i Vicedegana de la Facultat de Ciències i Cap d'Estudis de Biologia entre els anys 2012-2016.",
#   'CV_esp': 'No existe CV en este idioma',
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Genètica humana',
#   'Nombre': 'Marta Bassitta Sánchez',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Sra.',
#   'Relacion UIB': 'Titulada superior',
#   'CV_cat': 'No existe CV en este idioma',
#   'CV_esp': 'Licenciada en Biología por la Universidad de las Islas Baleares. Máster en Biotecnología, Genética y Biología celular. Estudiante Doctorado en Biotecnología biomédica y evolutiva (último año). Contratada Capitulo VI (Titulada Superior).',
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Genètica humana',
#   'Nombre': 'José Antonio Jurado Rivera',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Col·laboradors',
#   'Titulo': 'Dr.',
#   'Relacion UIB': 'Professor contractat doctor interí',
#   'CV_cat': "Llicenciat en Biologia per la Universidad de Granada (2002) i Doctor en Biologia per la UIB (2015). Ha realitzat estades de recerca a British Natural History Museum (London, UK), Australian Museum (Sydney, Australia), Western Australian Museum (Perth, Australia), Reserva Biológica Alberto Manuel Brenes (Costa Rica), Institut de Biologia Evolutiva (CSIC, Barcelona), Institut Agronomique Neo-Caledonien (Nova Caledònia) finançat pel Govern Espanyol, per la UE, i per la National Geographic Society. Des de 2009 a 2014 va estar vinculat amb contractes de recerca a l'Institut Mediterrani d'Estudis Avançats (IMEDEA, CSIC). Durant 5 anys va ser Professor Associat del Departament de Biologia (Genètica) de la UIB (2010-2014). Va posteriorment obtenir un contracte com a Professor Ajudant Doctor a la mateixa institució (2015). Durant l'etapa doctoral va treballar en l'estudi molecular basat en seqüències d'ADN de les relacions evolutives i la història biogeogràfica d'artròpodes. A més, va desenvolupar un estudi pioner dirigit a la caracterització molecular de les interaccions tròfiques en sistemes d'insectes herbívors. Ha estat investigador de 8 projectes de recerca. Temes d'interès: Biologia Evolutiva, Sistemàtica Molecular, Biogeografia, Evolució Molecular. Llista de publicacions científiques a ResearchID: http://www.researcherid.com/rid/H-2497-2015",
#   'CV_esp': 'No existe CV en este idioma',
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Genètica humana',
#   'Nombre': 'Joana Francesca Ferragut Simonet',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Col·laboradors',
#   'Titulo': 'Dra.',
#   'Relacion UIB': 'Professora ajudanta doctora',
#   'CV_cat': "Llicenciada en Biologia per la Universitat de les Illes Balears. Màster en Biotecnologia, Genètica i Biologia cel·lular i Màster en Formació al Professorat per la UIB. Doctorat de Biotecnologia, Genètica i Biologia cel·lular en la línia d'investigació de Genètica evolutiva en poblacions humanes amb el títol 'Genetic Legacy of Sephardic Jews: Paternal and Maternal lineages of Chueta population'. Ajudant doctor a l'àrea de Genètica des del curs 2018-2019.",
#   'CV_esp': "Licenciada en Biología por la Universidad de las Islas Baleares. Master en Biotecnología, Genética y Biología celular y Master en Formación al Profesorado por la UIB. Doctorado en Biotecnología, Genética y Biología celular en la línea de investigación de Genética evolutiva en poblaciones humanas con el título 'Genetic Legacy of Sephardic Jews: Paternal and Maternal lineages of chueta population'. Ayudante doctor en el área de Genética desde el curso 2018 a 2019.",
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Genètica humana',
#   'Nombre': 'Maria Magdalena Parera Rossello',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Col·laboradors',
#   'Titulo': 'Dra.',
#   'Relacion UIB': 'Professora associada',
#   'CV_cat': 'No tiene CV en este idioma',
#   'CV_esp': 'No tiene CV en este idioma',
#   'CV_eng': 'No tiene CV en este idioma'},
#  {'Grupo': 'Genètica humana',
#   'Nombre': 'Iris Alemany Hermoso',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Col·laboradors',
#   'Titulo': 'Sra.',
#   'Relacion UIB': 'CAIB -> Contractada predoctoral',
#   'CV_cat': 'No tiene CV en este idioma',
#   'CV_esp': 'No tiene CV en este idioma',
#   'CV_eng': 'No tiene CV en este idioma'},
#  {'Grupo': 'Genètica humana',
#   'Nombre': 'Joana Maria Buades Payeras',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Col·laboradors',
#   'Titulo': 'Sra.',
#   'Relacion UIB': 'CAIB -> Contractada predoctoral',
#   'CV_cat': 'No tiene CV en este idioma',
#   'CV_esp': 'No tiene CV en este idioma',
#   'CV_eng': 'No tiene CV en este idioma'},
#  {'Grupo': 'Genètica humana',
#   'Nombre': 'Virginia Rodríguez Delgado',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Col·laboradors',
#   'Titulo': 'Sra.',
#   'Relacion UIB': 'CAIB -> Contractada predoctoral',
#   'CV_cat': 'No tiene CV en este idioma',
#   'CV_esp': 'No tiene CV en este idioma',
#   'CV_eng': 'No tiene CV en este idioma'},
#  {'Grupo': 'Genètica humana',
#   'Nombre': 'Beatriz Sánchez Barceló',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Col·laboradors',
#   'Titulo': 'Sra.',
#   'Relacion UIB': 'Professora associada',
#   'CV_cat': 'No tiene CV en este idioma',
#   'CV_esp': 'No tiene CV en este idioma',
#   'CV_eng': 'No tiene CV en este idioma'},
#  {'Grupo': 'Microbiologia (Microbio)',
#   'Nombre': 'Rafael Bosch Zaragoza',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Investigador/a principal',
#   'Titulo': 'Dr.',
#   'Relacion UIB': "Professor titular d'universitat",
#   'CV_cat': "Soy licenciado con Grado en Biología por la Universidad de las Islas Baleares (1989) y Doctor en Biología por la misma Universidad (1994). He sido profesor de Microbiología de la UIB desde el curso académico 1994-95 con diferentes categorías contractuales, habiendo realizado estancias puntuales de investigación en otros centros y participado en una campaña oceanográfica Antártica. Desde el curso académico 2008-09 soy Profesor Titular de Microbiología y estoy adscrito al Departamento de Biología de la UIB. He estado vinculado a trabajos de investigación en temáticas diferentes desde 1988: filogenia y citogenética de coleópteros (alumno colaborador, 1988-89), fijación de nitrógeno en Azotobacter vinelandii (becario predoctoral FPI, 1990-1994), degradación de hidrocarburos aromáticos en Pseudomonas (1995-actualidad) y miembros del grupo Roseobacter (2006-actualidad), así como ecofisiología del grupo Roseobacter en aguas costeras antropogenizadas (2001-actualidad). Desde el año 2010 he empezado a abordar varias de estas temáticas utilizando técnicas de alto rendimiento como la genómica y la proteómica. Esta actividad científica se ha realizado en el marco de un total de 25 proyectos científicos competitivos financiados, tanto internacionales (5) como nacionales (20), habiendo actuado como Investigador Principal en 4 de ellos. Como resultado de estos proyectos he presentado resultados experimentales en más de 60 congresos, muchos de los cuales se han plasmado en más de 30 artículos en revistas internacionales indexadas, así como varios capítulos de libro y 2 patentes. Además, he dirigido un total de 6 tesis doctorales y otros 6 proyectos Final de Máster de carácter investigador. Finalmente, y en este marco de formación de personal investigador, he participado en el diseño y soy director del 'Máster Universitario en Microbiología Avanzada' (curso académico 2006-07 hasta actualidad), así como del 'Doctorado en Microbiología Ambiental y Biomédica' (curso académico 2007-08), este último con mención de Excelencia.",
#   'CV_esp': "Soy licenciado con Grado en Biología por la Universidad de las Islas Baleares (1989) y Doctor en Biología por la misma Universidad (1994). He sido profesor de Microbiología de la UIB desde el curso académico 1994-95 con diferentes categorías contractuales, habiendo realizado estancias puntuales de investigación en otros centros y participado en una campaña oceanográfica Antártica. Desde el curso académico 2008-09 soy Profesor Titular de Microbiología y estoy adscrito al Departamento de Biología de la UIB. He estado vinculado a trabajos de investigación en temáticas diferentes desde 1988: filogenia y citogenética de coleópteros (alumno colaborador, 1988-89), fijación de nitrógeno en Azotobacter vinelandii (becario predoctoral FPI, 1990-1994), degradación de hidrocarburos aromáticos en Pseudomonas (1995-actualidad) y miembros del grupo Roseobacter (2006-actualidad), así como ecofisiología del grupo Roseobacter en aguas costeras antropogenizadas (2001-actualidad). Desde el año 2010 he empezado a abordar varias de estas temáticas utilizando técnicas de alto rendimiento como la genómica y la proteómica. Esta actividad científica se ha realizado en el marco de un total de 25 proyectos científicos competitivos financiados, tanto internacionales (5) como nacionales (20), habiendo actuado como Investigador Principal en 4 de ellos. Como resultado de estos proyectos he presentado resultados experimentales en más de 60 congresos, muchos de los cuales se han plasmado en más de 30 artículos en revistas internacionales indexadas, así como varios capítulos de libro y 2 patentes. Además, he dirigido un total de 6 tesis doctorales y otros 6 proyectos Final de Máster de carácter investigador. Finalmente, y en este marco de formación de personal investigador, he participado en el diseño y soy director del 'Máster Universitario en Microbiología Avanzada' (curso académico 2006-07 hasta actualidad), así como del 'Doctorado en Microbiología Ambiental y Biomédica' (curso académico 2007-08), este último con mención de Excelencia.",
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Microbiologia (Microbio)',
#   'Nombre': 'Jorge Lalucat Jo',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Dr.',
#   'Relacion UIB': 'Professor emèrit',
#   'CV_cat': 'No existe CV en este idioma',
#   'CV_esp': 'Part A. INFORMACIÓN PERSONAL A.1. Cargo actual Institución: Universitat Illes Balears (UIB) Departmento: Biología Catedrático Emérito Universidad (desde 2019) Código especialidad UNESCO: 241400-Microbiology Palabras clave: Microbiología ambiental, Taxonomía  A.2. Educación Licenciado en Biología por la Universitat de Barcelona (1972) Doctorado en Biología por la Universitat de Barcelona (1977)  A.3. Indicadores generales de investigación y producción científica Tramos de investigación reconocidos: 6 Úñtimo period reconocido: 2010-2015 Tesis doctorales dirigids en los últimos 10 años: 3 (2 co-dirigida con M. Gomila; 1 con A. Bennasar) Citas: 4881 total; 2121 desde 2015 (Google Scholar) Promedio de citas en los últimos 5 años: 425 Publicaciones en revistas del primer cuartil: 41 (Total publicacions 130) Índice h: 31 (ISI WOS); 31 (Scopus); 33 (Research Gate); 36 (Google Scholar) ORCID iD: 0000-0002-8350-6087  Part B. CV SUMMARY Líneas de investigación: Microbiología ambiental, Taxonomía y sitemática bacterianas, Degradación de hidrocarburos, fisiología microbiana Excelencia investigadora reconocida por la comunidad autónoma de les Illes Balears desde 2006. Períodos de 5 años de docencia reconocidos: 6 Períodos de 6 años de investigación reconocidos: 6  Estancias en otros centros: 1973-80 Institut für Mikrobiologie de la Universität Göttingen, Alemania (27 meses) 1983 School of Medicine, University of South Dakota, USA (2 meses) 1985 Dep. Biology, University of Norwich, Gran Bretaña (2 meses) 1987 Malmö General Hospital; University of Lund, Suecia (2 meses) 2007 University of Stanford, USA (1 mes) 2013 Joint Genome Institute, University of Berkeley, USA (1 mes)  Otras actividades académicas 1973-74 Becario predoctoral del DAAD (Servicio Alemásn de Intercambio Académico) 1976 Becario predoctoral del DAAD 1978 Premio extraordinario de doctorado 1980 Miembro de la Sociedad Española de Microbiología 1979-80 6 mese, premio de la Fundación Alexander von Humboldt 1982-8 6 tesis de final de grado supervisadas 1982-84 Director del Departamento de Microbiología de la Universidad de Palma de Mallorca 1987-2019 9 Tesis doctorales dirigidas (2 con M. Gomila; 1 con A .Bennasar) 1986 Organización del seminario Humboldt: \'Evolution of Microbial Metabolism\'. Palma de Mallorca 1986 Director del Departamento de Microbiología de la Universidad de Barcelona 1987 Vicedirector del Instituto de Estudios Avanzados (CSIC-UIB) 1988-90 Miembro de la junta de la Sociedad Española de Microbiología 1988-93 Director del Instituto de Estudios Avanzados de las Islas Baleares (CSIC-UIB) 1990-92 Vicedirector del Departamento de Biología Ambiental (UIB) 1995-96 Vicerrector de cooperación Exterior Universitat de les Illes Balears 1996 Organización del Symposium \'Biodegradation of Organic Pollutants\'. Palma de Mallorca. 2003 Miembro correspondiente de la Real Academia de Ciencias de Barcelona 2004-2012 Presidente del grupo especializado "Taxonomy, Phylogeny and Biodiversity" de la Sociedad Española de Microbiología 2007-2011 Vicerrector de Investigación de la Universitat de les Illes Balears 2011 Premio Jaume II de investigación reconocido por el Consell Insular de Mallorca otorgado al grupo de investigación "Microbiología" UIB  130 Publicaciones científicas: 114 en revistas indexadas (ISI, Scopus), 6 capítulos de libros, 6 publicaciones docentes o de divulgación  https://orcid.org/0000-0002-8350-6087 https://scholar.google.es/citations?user=3FSNH2EAAAAJ&hl=es',
#   'CV_eng': "Part A. PERSONAL INFORMATION A.1. Current position Institution: Universitat Illes Balears (UIB) Department: Biología Current position: Catedrático Emérito Universidad (since 2019) UNESCO speciality code: 241400-Microbiology Key words: Environmental Microbiology, Taxonomy  A.2. Education Bachelor's degree: Biology; Universitat de Barcelona (1972) Doctorate (PhD) universitat de Barcelona (1977)  A.3. General research indicators of the scientific production Recognized research periods: 6 Last recognized period: 2010-2015 PhD thesis supervised in the last 10 years: 3 (2 co-supervised with M. Gomila; 1 with A. Bennasar) Citations: 4881 total; 2121 since 2015 (Google Scholar) Mean citations last 5 years: 425 Publications in journals of the first quartile: 41 (Total publications 130) h index: 31 (ISI WOS); 31 (Scopus); 33 (Research Gate); 36 (Google Scholar)  Part B. CV SUMMARY Research lines: Environmental Microbiology; Bacterial taxonomy and systematics; Hydrocarbon degradation; Microbial physiology Research excellence recognized by the autonomous region of the Balearics since 2006. Recognized teaching periods of 5 years: 6 Recognized research periods of 6 years: 6  Visiting scholar: 1973-80 Institut für Mikrobiologie der Universität Göttingen, Germany (27 months) 1983 School of Medicine, University of South Dakota, USA (2 months) 1985 Dep. Biology, University of Norwich, Grait Britain (2 months) 1987 Malmö General Hospital; University of Lund, Sweden (2 months) 2007 University of Stanford, USA (1 month) 2013 Joint Genome Institute, University of Berkeley, USA (1 month)  Other academic activities 1973-74 DAAD Predoctoral fellow 1976 DAAD Predoctoral fellow 1978 Extraordinary Doctorate Award 1980 Member of the Sociedad Española de Microbiología 1979-80 6 months, Alexander von Humboldt Stiftung fellow 1982-8 6 Bachellor's thesis supervised 1982-84 Director of the Microbiology Departament at the Universidad de Palma de Mallorca 1987-2019 9 PhD thesis supervised (2 with M. Gomila; 1 with A.Bennasar) 1986 Organization of the Humboldt Seminar: 'Evolution of Microbial Metabolism'. Palma de Mallorca 1986 Director of the Microbiology Departament at the Universidad de Barcelona 1987 Vice-director of the Instituto de Estudios Avanzados (CSIC-UIB) 1988-90 Member of the board Sociedad Española de Microbiología 1988-93 Director of the Instituto de Estudios Avanzados de las Islas Baleares (CSIC-UIB) 1990-92 Vice-director Departamento de Biología Ambiental (UIB) 1995-96 Vice-rector for external cooperation Universitat de les Illes Balears 1996 Organization of the Symposium 'Biodegradation of Organic Pollutants'. Palma de Mallorca. 2003 Corresponding member of the Real Academia de Ciencias de Barcelona 2004-2012 President of the Specialized Group Taxonomy, Phylogeny and Biodiversity of the Sociedad Española de Microbiología 2007-2011 Vice-rector for Research at the Universitat de les Illes Balears 2011 Jaume II Research Award recognized by the Consell Insular de Mallorca to the research group 'Microbiología' of the UIB  130 Scientific Publications: 114 in indexed journals (ISI, Scopus), 6 book chapters, 6 teaching or dissemination publications"},
#  {'Grupo': 'Microbiologia (Microbio)',
#   'Nombre': 'Elena Isabel García-Valdés Pukkits',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Dra.',
#   'Relacion UIB': "Catedràtica d'universitat",
#   'CV_cat': "Fecha del CVA 15.09.2014 Elena García-Valdés Pukkits Núm. identificación del investigador Researcher ID K-1143-2014 Código Orcid 0000-0001-5829-0002 Organismo: Universitat de les Illes Balears (UIB) Dpto./Centro Dpto. Biología Categoría profesional Catedrática Universidad Palabras clave Microbiología ambiental, Taxonomía Sexenios investigación: 4 RESUMEN LIBRE DEL CURRÍCULUM. Trayectoria. Dedicación exclusiva a la Universidad desde hace 32 años como docente e investigadora. Miembro del grupo de investigación 'Microbiología' Dirección General de Investigación del Gobierno Balear. 4 sexenios reconocidos y todos los complementos de actividad y de excelencia investigadora de nuestra Comunidad Autónoma. Desde 2001 investigadora en proyectos del Plan Nacional, de los tres últimos he sido Investigadora Principal: (CGL-BOS: 2001, 2004, 2008 y 2011). He colaborado en un total de 29 proyectos nacionales e internacionales (HA Acción integrada 2001, BIO 1994, 1997 y 2000; VEM 2003; ANT 1997). Soy investigadora del proyecto CONSOLIDER-Ingenio 2010. He colaborado en redes internacionales de estudio de Pseudomonas: proyectos Health Canadá y GEBA (Leibniz Institut-DSM de Alemania y Joint Genome Institute de USA). Estancias en Gales, Inglaterra, Suecia, Stanford y Berkeley. Resultados: 51 artículos científicos, 6 de divulgación, una revisión y dos capítulos de libro. He participado en el Comité organizador de 3 Congresos Nacionales, en 74 presentaciones a Congresos (22 de las cuales internacionales: europeos, americanos y asiáticos. He dirigido 4 tesis de doctorado cada una ha dado lugar a 3-4 artículos científicos. Transferencia de resultados al sector productivo en proyectos de colaboración con: TIRME (gestión de residuos), Embutidos Munar, Industrias queseras mallorquinas, PURAQ (producción ácido láctico). Nuestro grupo de trabajo posee una trayectoria coherente de 30 años en microbiología ambiental, basada en parte en el estudio taxonómico del género Pseudomonas, inicialmente con la especie Pseudomonas stutzeri (descripción de 22 genomovares) extendido posteriormente a todo el género. Se han descrito nuevas especies: P. balearica, P. entomophila, P. aestusnigri y P. alkylphenolia se ha redefinido el grupo P. putida. Se han introducido nuevas metodologías para el estudio del género (MLSA, MALDI-TOF, pirosecuenciación, genómica) y se han construido bases de datos moleculares. Responsable de la creación y mantenimiento de una colección de cepas de referencia de Pseudomonas, actualizada a medida que surgen nuevas especies y que supera a la de cualquier colección nacional o internacional. Junto con las cepas tipo disponemos de unas 400 cepas del género bien caracterizadas. Se han depositado en Bases de datos 953 secuencias. Hitos conseguidos: 1º El análisis multilocus o (Mulet 2010, Mulet 2012) es el referente en la descripción del género Pseudomonas. 2º Concepto de 'genomovar' hoy en día aceptado por la comunidad científica. 3º Se han secuenciado y analizado 16 genomas del género Pseudomonas. 4º Desarrollo de un método basado en PCR aplicable a métodos independientes de cultivo para detectar Pseudomonas. Intereses: Avanzar en la filogenómica del género aplicando el análisis de genomas completos. Descripción de nuevas especies de diversos orígenes depositadas en nuestra colección cepas: patógenos vegetales (Irán), de suelos (Mallorca), de río (Bélgica), de cuevas (Mallorca), cepas clínicas de aguas de hemodiálisis o laboratorio (Mallorca y Suecia). 12/09/ 2009 Premio Jaime II de Investigación, Consell Insular de Mallorca al Grupo de Microbiología",
#   'CV_esp': "Fecha del CVA 15.09.2014 Elena García-Valdés Pukkits Núm. identificación del investigador Researcher ID K-1143-2014 Código Orcid 0000-0001-5829-0002 Organismo: Universitat de les Illes Balears (UIB) Dpto./Centro Dpto. Biología Categoría profesional Catedrática Universidad Palabras clave Microbiología ambiental, Taxonomía Sexenios investigación: 4 RESUMEN LIBRE DEL CURRÍCULUM. Trayectoria. Dedicación exclusiva a la Universidad desde hace 32 años como docente e investigadora. Miembro del grupo de investigación 'Microbiología' Dirección General de Investigación del Gobierno Balear. 4 sexenios reconocidos y todos los complementos de actividad y de excelencia investigadora de nuestra Comunidad Autónoma. Desde 2001 investigadora en proyectos del Plan Nacional, de los tres últimos he sido Investigadora Principal: (CGL-BOS: 2001, 2004, 2008 y 2011). He colaborado en un total de 29 proyectos nacionales e internacionales (HA Acción integrada 2001, BIO 1994, 1997 y 2000; VEM 2003; ANT 1997). Soy investigadora del proyecto CONSOLIDER-Ingenio 2010. He colaborado en redes internacionales de estudio de Pseudomonas: proyectos Health Canadá y GEBA (Leibniz Institut-DSM de Alemania y Joint Genome Institute de USA). Estancias en Gales, Inglaterra, Suecia, Stanford y Berkeley. Resultados: 51 artículos científicos, 6 de divulgación, una revisión y dos capítulos de libro. He participado en el Comité organizador de 3 Congresos Nacionales, en 74 presentaciones a Congresos (22 de las cuales internacionales: europeos, americanos y asiáticos. He dirigido 4 tesis de doctorado cada una ha dado lugar a 3-4 artículos científicos. Transferencia de resultados al sector productivo en proyectos de colaboración con: TIRME (gestión de residuos), Embutidos Munar, Industrias queseras mallorquinas, PURAQ (producción ácido láctico). Nuestro grupo de trabajo posee una trayectoria coherente de 30 años en microbiología ambiental, basada en parte en el estudio taxonómico del género Pseudomonas, inicialmente con la especie Pseudomonas stutzeri (descripción de 22 genomovares) extendido posteriormente a todo el género. Se han descrito nuevas especies: P. balearica, P. entomophila, P. aestusnigri y P. alkylphenolia se ha redefinido el grupo P. putida. Se han introducido nuevas metodologías para el estudio del género (MLSA, MALDI-TOF, pirosecuenciación, genómica) y se han construido bases de datos moleculares. Responsable de la creación y mantenimiento de una colección de cepas de referencia de Pseudomonas, actualizada a medida que surgen nuevas especies y que supera a la de cualquier colección nacional o internacional. Junto con las cepas tipo disponemos de unas 400 cepas del género bien caracterizadas. Se han depositado en Bases de datos 953 secuencias. Hitos conseguidos: 1º El análisis multilocus o (Mulet 2010, Mulet 2012) es el referente en la descripción del género Pseudomonas. 2º Concepto de 'genomovar' hoy en día aceptado por la comunidad científica. 3º Se han secuenciado y analizado 16 genomas del género Pseudomonas. 4º Desarrollo de un método basado en PCR aplicable a métodos independientes de cultivo para detectar Pseudomonas. Intereses: Avanzar en la filogenómica del género aplicando el análisis de genomas completos. Descripción de nuevas especies de diversos orígenes depositadas en nuestra colección cepas: patógenos vegetales (Irán), de suelos (Mallorca), de río (Bélgica), de cuevas (Mallorca), cepas clínicas de aguas de hemodiálisis o laboratorio (Mallorca y Suecia). 12/09/ 2009 Premio Jaime II de Investigación, Consell Insular de Mallorca al Grupo de Microbiología",
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Microbiologia (Microbio)',
#   'Nombre': 'Antonio Bennàsar Figueras',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Dr.',
#   'Relacion UIB': "Professor titular d'universitat",
#   'CV_cat': "Antoni Bennasar Figueras (d'ara endavant, ABF) és Doctor en Biologia per la Universitat de les Illes Balears (1995). A més de Professor i Investigador de l'Àrea de Microbiologia des de l'any 2000, ABF ha estat responsable de l'Àrea de Biotecnologia de l'empresa GridSystems (2001-03) i President Fundador de Biogenia Research (2003-05), una empresa spin-off de la UIB de base biotecnològica. L'empresa Biogenia Research va ser premiada en el VI Concurs de Projectes Empresarials (2003) i al millor projecte de Mallorca del III Concurs d'Innovació Illes Balears en la modalitat d'idees de projectes d'innovació tecnològica (2004). A partir del desenvolupament de la seva Tesi Doctoral (1995) i fins a l'actualitat, ABF ha dedicat gran part de la seva activitat professional als àmbits de la microbiologia ambiental aplicada, seguretat i traçabilitat alimentària, l'aplicació de mètodes d'anàlisis microbiològiques; i especialment al desenvolupament d'estratègies i tècniques avançades per a la detecció, identificació i caracterització de microorganismes (Legionella, Pseudomonas, Salmonella, Mycobacterium, Caulobacter). En aquest sentit, és de destacar el desenvolupament d'un mètode altament sensible per a la detecció de aflatoxinas en aliments mitjançant la tècnica de inmuno-PCR. El contacte amb la realitat empresarial ha permès a ABF adquirir experiència en la identificació i caracterització fenotípica i molecular de microorganismes patògens; especialment d'aquells relacionats amb el control de qualitat i la seguretat alimentària. A més, les responsabilitats exercides en GridSystems i Biogenia Research, la participació com a investigador principal en dos projectes de genòmica del Pla Nacional i com a investigador en un projecte CONSOLIDER (Microgen); han permès a ABF adquirir els coneixements en bioinformática necessaris per a la seva especialització en l'assemblatge, anotació i anàlisi comparativa de genomes de microorganismes; així com per a la construcció i manteniment de bases de dades de genòmica i proteòmica. En resum, ABF comptabilitza en l'actualitat cinc quinquennis o mèrits de docència i quatre sexennis o mèrits de recerca reconeguts per la ANECA. La consolidació i continuada actualització dels diferents coneixements adquirits a través de l'experiència investigadora i de les incursions al món empresarial, constitueixen els pilars essencials sobre els quals ABF pretén sustentar una labor docent integradora, que permeti oferir una formació innovadora i amb perspectives de futur a les noves generacions de Microbiòlegs en l'àmbit de les anàlisis microbiològiques.",
#   'CV_esp': 'Antoni Bennasar Figueras (de ahora en adelante, ABF) es Doctor en Biología por la Universitat de les Illes Balears (1995). Además de Profesor e Investigador del Área de Microbiología desde el año 2000, ABF ha sido responsable del Área de Biotecnología de la empresa GridSystems (2001-03) y Presidente Fundador de Biogenia Research (2003-05), una empresa spin-off de la UIB de base biotecnológica. La empresa Biogenia Research fue premiada en el VI Concurso de Proyectos Empresariales (2003) y al mejor proyecto de Mallorca del III Concurso de Innovación Illes Balears en la modalidad de ideas de proyectos de innovación tecnológica (2004). A partir del desarrollo de su Tesis Doctoral (1995) y hasta la actualidad, ABF ha dedicado gran parte de su actividad profesional a los ámbitos de la microbiología ambiental aplicada, seguridad y trazabilidad alimentaria, la aplicación de métodos de análisis microbiológicos; y en especial al desarrollo de estrategias y técnicas avanzadas para la detección, identificación y caracterización de microorganismos (Legionella, Pseudomonas, Salmonella, Mycobacterium, Caulobacter). En este sentido, es de destacar el desarrollo de un método altamente sensible para la detección de aflatoxinas en alimentos mediante la técnica de inmuno-PCR. El contacto con la realidad empresarial ha permitido a ABF adquirir experiencia en la identificación y caracterización fenotípica y molecular de microorganismos patógenos; en especial de aquellos relacionados con el control de calidad y la seguridad alimentaria. Además, las responsabilidades desempeñadas en GridSystems y Biogenia Research, la participación como investigador principal en dos proyectos de genómica del Plan Nacional y como investigador en un proyecto CONSOLIDER (Microgen); han permitido a ABF adquirir los conocimientos en bioinformática necesarios para su especialización en el ensamblaje, anotación y análisis comparativo de genomas de microrganismos; así como para la construcción y mantenimiento de bases de datos de genómica y proteómica. En resumen, ABF contabiliza en la actualidad cinco quinquenios o méritos de docencia y cuatro sexenios o méritos de investigación reconocidos por la ANECA. La consolidación y continuada actualización de los distintos conocimientos adquiridos a través de la experiencia investigadora y de las incursiones en el mundo empresarial, constituyen los pilares esenciales sobre los que ABF pretende sustentar una labor docente integradora, que permita ofrecer una formación innovadora y con perspectivas de futuro a las nuevas generaciones de Microbiólogos en el ámbito de los análisis microbiológicos.',
#   'CV_eng': "Antoni Bennasar Figueras (from now on, ABF) is Doctor in Biology from the Universitat de les Illes Balears (1995). In addition to Professor and Researcher of the Microbiology Area since 2000, ABF has been the responsible for the Biotechnology Department of the company GridSystems (2001-03) and the Founder President of Biogenia Research (2003-05), a spin-off biotechnology based company of the UIB. The Biogenia Research company was awarded at the VI Business Projects Contest (2003) and as the best project in Mallorca of the III Illes Balears Innovation Competition, in the modality of ideas for technological innovation projects (2004). Since the development of the Doctoral Thesis (1995) and to date, ABF has devoted much of his professional activity to the areas of applied environmental microbiology, molecular microbial ecology, characterization of microbial communities, biological containment systems for recombinant bacteria, food safety and traceability, the application of microbiological analysis methods; and especially to the development of advanced strategies and techniques for the detection, identification and characterization of microorganisms (Legionella, Pseudomonas, Salmonella, Mycobacterium, Caulobacter). In this regard, it is noteworthy the development of a highly sensitive method, based on the immuno-PCR technique, for the detection of aflatoxins in foods. The experience acquired in the business world has allowed ABF to gain skills for the phenotypic identification and molecular characterization of pathogenic microorganisms; especially those related to the food quality control and safety. The responsibilities performed in GridSystems and Biogenia Research, its participation as a main researcher in two genomics projects of the Spanish National Plan for research and as a researcher in a CONSOLIDER project (Microgen); have allowed ABF to specialize in the application of new high-performance sequencing technologies NGS (Next Generation Sequencing) to microbiology and to acquire the necessary knowledge and know-how in bioinformatics for the assembly, annotation and comparative analysis of microorganism genomes; as well as for the construction, maintenance and mining of databases. ABF is currently an active member at the Research Group of the Microbiology Area of the Department of Biology of the Universitat de les Illes Balears (UIB) and the Institut Universitari d'Investigació en Ciències de la Salut (IUNICS). As responsible for the experimentation with biological agents, ABF has been the Vice-President (2014-18) and the President of the Biosafety Committee of the UIB (since june 2018). In summary, ABF currently has four five-year periods (quinquenios) or teaching merits and four six-year terms (sexenios) or research merits recognized by ANECA. The consolidation and continuous updating of the different knowledge and skills acquired through the research experience and the incursions into the biotechnology business world, constitute the essential pillars on which ABF intends to sustain both teaching and research work in an integrating manner, which allows the development of innovative research and offers training with promising perspectives to new student generations in the Microbiology field."},
#  {'Grupo': 'Microbiologia (Microbio)',
#   'Nombre': 'Margarita Gomila Ribas',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Dra.',
#   'Relacion UIB': "Professora titular d'universitat",
#   'CV_cat': "Soc Llicenciada en Biologia (1999) i en Bioquimica (2000) per la Universitat de les Illes Balears, i Doctora en Biologia per la mateixa universitat en 2007, obtenint el títol de Doctora Europea i el Premi extraordinari de doctorat del meu bienni. Durant la meva etapa pre-doctoral i post-doctoral he realitzat diferents estades de treball a l'estranger, a Anglaterra, Alemanya i Suècia. La meva experiència professional es centra en l'ecologia molecular microbiana, particularment en l'estudi de la microbiota present en ambients aquàtics. Estic interessada principalment en biodiversitat i actualment treballo en varies disciplines, incloent la microbiologia clínica, taxonomia, filogènia, sistemàtica, genòmica i metagenòmica. He participat activament en més de 40 projectes nacionals i internacionals, essent la investigadora principal en quatre d'ells. El darrer projecte al qual estic adscrita es una Innovative Training Network finançada amb fons europeus. En el meu currículum vitae figuren dos capítols de llibre, tres articles de divulgació i més de 70 publicacions. Soc la primera autora a 23 d'elles, la segona a quinze i la darrera a tres. Com a resultat d'aquests projectes he participat en més de 80 conferències nacionals i internacionals, i els mèrits de la meva investigació han estat reconeguts en quatre premis, tres en conferències i un a nivell local. Pel que fa a la meva activitat docent, tinc àmplia experiència docent a distints nivells. Durant la meva carrera científica he contribuït a l'ensenyament de estudiants de grau i llicenciatura, en projectes d'inici a la investigació i he dirigit més de 15 projectes de final de màster, així com codirigit tres tesis doctorals. Actualment dirigeixo una tesis doctoral i en codirigeixo una altra.",
#   'CV_esp': 'Soy Licenciada en Biología (1999) y en Bioquímica (2000) por la Universidad de las Islas Baleares, y Doctora en Biología por la misma universidad en 2007, obteniendo el titulo de Doctora Europea y el Premio extraordinario de doctorado de mi bienio. Durante mi etapa predoctoral y postdoctoral he realizado distintas estancias en el extranjero, en Inglaterra, Alemania y Suecia. Mi experiencia profesional se centra en la ecología molecular microbiana, particularmente en el estudio de la microbiota presente en ambientes acuáticos. Estoy interesada principalmente en biodiversidad y actualmente trabajo en varias disciplinas, incluyendo la microbiología clínica, taxonomía, filogenia, sistemática, genómica y metagenómica. He participado activamente en más de 40 proyectos nacionales e internacionales, siendo la investigadora principal en cuatro de ellos. El último proyecto al que estoy adscrita es una Innovative Training Network financiado con fondos europeos. En mi curriculum vitae figura dos capitulos de libro, tres artículos de divulgación y más de 70 publicaciones. Soy la primera autora en 23 de ellas, la segunda en 15 y la última en tres. Como resultado de estos proyectos he participado en más de 80 conferencias nacionales e internacionales, y los méritos de mi investigación han sido reconocidos con cuatro premios, tres en conferencias y uno a nivel local. En cuanto a mi actividad docente, tengo experiencia docente a distintos niveles. Durante mi carrera científica he contribuido a la enseñanza de estudiantes de grado y licenciatura, en proyectos de iniciación a la investigación y he dirigido más de 15 proyectos finales de máster, así como codirigido tres tesis doctorales. Actualmente dirijo una tesis doctoral y codirijo otra.',
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Microbiologia (Microbio)',
#   'Nombre': 'Balbina Nogales Fernández',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Dra.',
#   'Relacion UIB': "Professora titular d'universitat",
#   'CV_cat': "Sóc llicenciada en Ciències Biològiques por la Universitat Autònoma de Barcelona (1990), i Doctora en Ciències Biològiques por la mateixa universitat (1996). A la finalització de la meva tesis vaig fer un període de formació postdoctoral a l'estranger entre els anys 1996-2000. Aquest any em vaig incorporar a la UIB, primer com investigadora contractada i posteriorment com investigadora Ramón y Cajal en el Departament de Biologia (2003-2008), Professora Contractada Dra. del programa I3 (2008-2011) y finalment Professora Titular de Microbiologia (des de 2011). Sóc docent a la UIB des del curs 2005-2006 tant en llicenciatura/grau de Biologia com en formació de postgrau (Màster en Microbiologia Avançada i Doctorat en Microbiologia Ambiental i Biomèdica). He codirigit sis tesis doctorals. La meva activitat investigadora s' emmarca en el camp de la microbiologia ambiental des de la meva tesis doctoral. La tesis es va centrar en l'estudi de relacions antagòniques per microorganismes fototròfics del sofre, amb un caire d'ecofisiologia microbiana. A partir del postdoctorat la meva investigació es va centrar en l'estudi de comunitats microbianes d'ambients contaminats. A la UIB he creat un equip d'investigació amb el Dr. Rafael Bosch, que està integrat en el Grup de Microbiologia. Actualment la nostra investigació es centra en l'estudi de la diversitat bacteriana en ambientes marins contaminats crònicament per hidrocarburs, i en el paper del grup Roseobacter en la degradació d'aquests contaminants. Combinem l'anàlisi global de comunitats microbianes (metagenòmica) amb un anàlisis genòmic, bioquímic i fisiològic (genòmica i proteòmica) d'aïllats degradadors d'hidrocarburs. Durant la meva trajectòria investigadora he participat en 23 projectes o accions de recerca europeus, nacionals o regionals, i he estat investigadora principal de 6 d'ells, així com d'un conveni amb empresa. Els resultats de la meva recerca s'ha publicat en revistes Internacionals (ID ORCID 0000-0001-5769-9500) i han estat presentats en congressos nacionals i internacionals. Sóc membre de l'Editorial Board de les revistes Environmental Microbiology/Environmental Microbiology Reports i FEMS Microbiology Ecology, així com de diverses societats científiques (Societat Catalana de Biologia, Sociedad Española de Microbiología, Sociedad Española de Biotecnología, Society for Applied Microbiology UK).",
#   'CV_esp': 'Soy licenciada en Ciencias Biológicas por la Universidad Autónoma de Barcelona (1990), y Doctora en Ciencias Biológicas por la misma universidad (1996). A la finalización de mi tesis realicé un periodo de formación postdoctoral en el extranjero entre los años 1996-2000. Ese año me incorporé a la UIB, primero como investigadora contratada y posteriormente como investigadora Ramón y Cajal en el Departamento de Biología (2003-2008), Profesora Contratada Dra. del programa I3 (2008-2011) y finalmente Profesora Titular de Microbiología (desde 2011). Soy docente en la UIB desde el curso 2005-2006 tanto en licenciatura/grado de Biología como en formación de postgrado (Máster en Microbiología Avanzada y Doctorado en Microbiología Ambiental y Biomédica). He codirigido seis tesis doctorales. Mi actividad investigadora se enmarca en el campo de la microbiología ambiental desde mi tesis doctoral. Mi tesis se centró en el estudio de relaciones antagónicas para microorganismos fototróficos del azufre, con un enfoque de ecofisiología microbiana. A partir del postdoctorado mi investigación se centró en el estudio de comunidades microbianas de ambientes contaminados. En la UIB he creado un equipo de investigación con el Dr. Rafael Bosch, que está integrado en el Grupo de Microbiología. Actualmente nuestra investigación se centra en el estudio de la diversidad bacteriana en ambientes marinos contaminados crónicamente por hidrocarburos, y en el papel del grupo Roseobacter en la degradación de estos contaminantes. Combinamos el análisis global de comunidades microbianas (metagenómica) con un análisis genómico, bioquímico y fisiológico (genómica y proteómica) de aislados degradadores de hidrocarburos. Durante mi trayectoria investigadora he participado en 23 proyectos o acciones de investigación europeos, nacionales o regionales, y he sido investigadora principal de 6 de ellos, así como de un convenio con empresa. Los resultados de mis investigaciones se han publicado en revistas internacionales (ID ORCID 0000-0001-5769-9500) y han sido presentados en congresos nacionales e internacionales. Soy miembro del Editorial Board de las revistas Environmental Microbiology/Environmental Microbiology Reports y FEMS Microbiology Ecology, así como de diversas sociedades científicas (Societat Catalana de Biologia, Sociedad Española de Microbiología, Sociedad Española de Biotecnología, Society for Applied Microbiology UK).',
# ...
#   'CV_eng': "Dr. Miquel Barceló is PhD in Chemistry by the UIB and was a postdoc at University of Zurich.He is professor of Inorganic Chemistry at the Chemistry Department since 2008.His research is devoted to the study of metal ions interacting with molecules with biological/pharmacological interest, to the crystallography and, mainly, to the study of RNA riboswitches. He is part of the Bioinorganic and Bioorganic Chemistry Research Group. He has presented more than 50 communications at conferences (mainly internationals), with and Invited Lecture at ICBIC-19 (Switzerland 2019) and Oral Communications at EuroBIC-13 (Hungary 2016), ISABC-13 (Irland 2015), EuroBIC-12 (Switzerland 2014) and XI International Symposium on Inorganic Biochemistry (Poland 2010). He has published 41 research papers, 2 conference proceedings, 2 review papers and 1 book's chapter, in impact journals, which have received 779 citations (two most cited papers have received 84 and 72 citations, respectively), and his H index is 16. He have supervised 1 PhD, 5 Master's thesis and 7 grading projects. He have 2 research periods (sexenios) and 2 teaching periods (quinquenios)."},
#  {'Grupo': 'Química bioinorgànica i bioorgànica (QUIMIBIO)',
#   'Nombre': 'Adela López Zafra',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Dra.',
#   'Relacion UIB': 'Professora associada',
#   'CV_cat': 'No existe CV en este idioma',
#   'CV_esp': 'La Doctora Adela López és profesora asociada desde el 2007\xa0del departamento de química-área Inorgánica.',
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Química de materials (MATER)',
#   'Nombre': 'Gemma Isabel Turnes Palomino',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Investigador/a principal',
#   'Titulo': 'Dra.',
#   'Relacion UIB': "Catedràtica d'universitat",
#   'CV_cat': "La Dra. Gemma Turnes és Catedràtica d'Universitat de Química Inorgànica en el Departament de Química de la Universitat de les Illes Balears i investigadora principal del grup de química de materials (MATER). En l'actualitat és a més directora de Departament de Química i sotsdirectora del Laboratori de Química Analítica Ambiental de la UIB. La seva recerca se centra en la síntesi i caracterització de sòlids porosos (especialment zeolites, xarxes metalo-orgàniques i carbonis porosos), així com materials híbrids derivats d'ells (membranes, esponges, suports preparats mitjançant impressió 3D, etc.), per a la seva aplicació en l'emmagatzematge de gasos, catàlisi i extracció de contaminants ambientals. És coautora de més de 100 publicacions en revistes científiques internacionals dels camps de la Química Inorgànica, la Química Física, la Química Analítica, la Química de Superfícies i la Catàlisi (índex h: 35). Ha participat i liderat projectes d'investigació obtinguts en convocatòries competitives (europees, nacionals i autonòmiques) així com en diversos contractes amb empreses. Té reconeguts quatre sexennis d'investigació i cinc quinquennis de docència. Ha dirigit cinc treballs fi de grau, dos treballs per a l'obtenció de la suficiència investigadora, vuit treballs fi de màster i set tesis doctorals. En aquests moments està dirigint dos treballs fi de màster i quatre tesis doctorals.",
#   'CV_esp': 'La Dra. Gemma Turnes es Catedrática de Universidad de Química Inorgánica en el Departamento de Química de la Universidad de las Islas Baleares (UIB) e investigadora principal del grupo de química de materiales (MATER). En la actualidad es además Directora del Departamento de Química y subdirectora del Laboratorio de Química Analítica Ambiental de la UIB. Su investigación se centra en la síntesis y caracterización de sólidos porosos (especialmente zeolitas, redes metalo-orgánicas y carbones porosos) así como de materiales híbridos derivados de ellos (membranas, esponjas, soportes preparados mediante impresión 3D, etc), para su aplicación en el almacenamiento de gases, catálisis y extracción de contaminantes ambientales. Es coautora de más de 100 publicaciones en revistas científicas internacionales de los campos de la Química Inorgánica, la Química Física, la Química Analítica, la Química de Superficies y la Catálisis (índice h: 35). Ha participado y liderado proyectos de investigación obtenidos en convocatorias competitivas (europeas, nacionales y autonómicas) así como en diversos contratos con empresas. Tiene reconocidos cuatro sexenios de investigación y cinco quinquenios de docencia. Ha dirigido cinco trabajos fin de grado, dos trabajos para la obtención de la suficiencia investigadora, ocho trabajos fin de máster y siete tesis doctorales. En estos momentos está dirigiendo dos trabajos fin de máster y cuatro tesis doctorales.',
#   'CV_eng': "Dr. Gemma Turnes is Professor of Inorganic Chemistry of the Department of Chemistry of the University of the Balearic Islands(UIB) and main researcher of the materials chemistry group (MATER). At present, she is also Director of the Department of Chemistry and deputy director of the Laboratory of Environmental Analytical Chemistry of the UIB. Her research is focused on the synthesis and characterization of porous solids (especially zeolites, metallo-organic frameworks and porous carbons), and hybrid materials derived from them (membranes, sponges, 3D-printed supports, etc.), for gas storage, catalysis and environmental pollutants extraction. She has co-authored more than 100 publications in international scientific journals of Inorganic Chemistry, Physical Chemistry, Analytical Chemistry, Surface Chemistry and Catalysis (h index: 35). She has participated and led several research projects obtained in competitive calls (european, national and regional) as well as in various R&D contracts. She has advised eight master's degree projects and seven doctoral theses and is currently directing two master's projects and four doctoral theses."},
#  {'Grupo': 'Química de materials (MATER)',
#   'Nombre': 'Montserrat Rodríguez Delgado',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Dra.',
#   'Relacion UIB': "Professora titular d'universitat",
#   'CV_cat': 'La Dra. Montserrat Rodríguez Delgado es profesora de Química Inorgánica en el Departamento de Química de la Universidad de las Islas Baleares desde 2006. Actualmente es Vicedecana de la Facultad de Ciencias y jefa de estudios del Grado de Química. Su investigación se centra en el estudio de materiales porosos para la adsorción de gases y activación de moléculas absorbidas y para la retención de contaminantes ambientales. Tiene reconocidos dos quinquenios de docencia y dos sexenios de investigación.',
#   'CV_esp': 'No existe CV en este idioma',
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Química de materials (MATER)',
#   'Nombre': 'Carlos Palomino Cabello',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Dr.',
#   'Relacion UIB': 'Professor contractat doctor interí',
#   'CV_cat': 'No existe CV en este idioma',
#   'CV_esp': 'El Dr. Carlos Palomino Cabello es profesor contratado doctor interino de Química Inorgánica en el Departamento de Química de la Universidad de las Islas Baleares desde 2019. Realiza su labor investigadora en el grupo de química de materiales (MATER) y colabora de forma continuada con el grupo de Química Analítica, Automatitzación y Medio Ambiente de la UIB. Su investigación se centra en la síntesis y caracterización de sólidos porosos (especialmente zeolitas, estructuras metalo-orgánicas y carbonos porosos) y materiales híbridos derivados de ellos (membranas, esponjas, soportes preparados mediante impresión 3D, etc), para el almacenamiento de gases, la catálisis y la extracción de contaminantes ambientales. Es coautor de 37 publicaciones en revistas científicas internacionales de reconocido prestigio (índice H: 17). A lo largo de su carrera profesional ha participado en 37 conferencias internacionales y ha participado activamente en proyectos de investigación obtenidos en convocatorias competitivas (5 nacionales y 2 autonómicos). Ha supervisado 1 tesis doctoral, 3 proyectos de máster, 2 proyectos de final de grado y 2 estudiantes colaboradores. Actualmente está supervisando tres tesis doctorales. Tiene reconocidos dos quinquenios de docencia y un sexenio de investigación. ResearchID: https://publons.com/researcher/1459421',
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Química de materials (MATER)',
#   'Nombre': 'Paolo Rumori',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Dr.',
#   'Relacion UIB': 'Professor associat',
#   'CV_cat': "El Dr. Paolo Rumori es professor associat de Química Inorgànica en el Departament de Química de la Universitat de les Illes Balears des de 2004. La seva investigació es centra en l'estudi de materials porosos per al seu us com a adsorbents i catalitzadors.",
#   'CV_esp': 'El Dr. Paolo Rumori es profesor asociado de Química Inorgánica en el Departamento de Química de la Universidad de las Islas Baleares desde 2004. Su investigación se centra en el estudio de materiales porosos para su uso como adsorbentes y catalizadores.',
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Química de materials (MATER)',
#   'Nombre': 'Ana Maria Canaleta Safont',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Sra.',
#   'Relacion UIB': 'Professora associada',
#   'CV_cat': 'No existe CV en este idioma',
#   'CV_esp': "La Dra. Ana Maria Canaleta Safont és professora associada de Química Inorgànica en el Departament de Química de la Universitat de les Illes Balears. Forma part del grup de recerca de Química de materials (MATER). La seva trajectòria professional es centre en el tractament del residus, amb 20 anys d'experiència en el sector, en àrees de producció, control de processos industrials, I+D+i, entre d'altres. Actualment és la cap de la Oficina d'Economia Circular i Desenvolupament Sostenible de Tirme.",
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Química de materials (MATER)',
#   'Nombre': 'Neus Crespí Sánchez',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Sra.',
#   'Relacion UIB': 'Contractada predoctoral FPU',
#   'CV_cat': '\xa0 \nEstudiant de doctorat a la Universitat de les Illes Balears, experiència en la preparació de materials híbrids porosos per a l’extracció de contaminants. \nDinàmica, proactiva, col·laborativa, capacitat de treball en equip i emprenedora.',
#   'CV_esp': 'No existe CV en este idioma',
#   'CV_eng': 'No existe CV en este idioma'},
#  {'Grupo': 'Química de materials (MATER)',
#   'Nombre': 'Mateo del Río Clar',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Sr.',
#   'Relacion UIB': 'CAIB -> Contractat predoctoral',
#   'CV_cat': 'No tiene CV en este idioma',
#   'CV_esp': 'No tiene CV en este idioma',
#   'CV_eng': 'No tiene CV en este idioma'},
#  {'Grupo': 'Química de materials (MATER)',
#   'Nombre': 'Marta Bauzá Manzanares',
#   'Genero': 'FEMENINO',
#   'Tipo de investigador': 'Membres',
#   'Titulo': 'Sra.',
#   'Relacion UIB': 'Titulada superior',
#   'CV_cat': 'No tiene CV en este idioma',
#   'CV_esp': 'No tiene CV en este idioma',
#   'CV_eng': 'No tiene CV en este idioma'},
#  {'Grupo': 'Química de materials (MATER)',
#   'Nombre': 'Fernando Maya Alejandro',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Col·laboradors',
#   'Titulo': 'Dr.',
#   'Relacion UIB': "Professor titular d'universitat",
#   'CV_cat': "Doctor en Química per la UIB (2011). Investigador postdoctoral/Fulbright Scholar en el Lawrence Berkeley National Laboratory (USA, 2012-2013). Ha realitzat estades de recerca en la University of Hull (UK), i ha estat investigador convidat per la University of Copenhagen (Dinamarca) i Fulbright Occasional Lecturer en la University of Minnesota Morris (USA).  La seva recerca es basa en el desenvolupament de nous materials i la seva integració sobre suports funcionals, facilitant el seu ús per a aplicacions de separació química.  Ha publicat 44 articles en revistes internacionals del camp de la química analítica (Anal. Chem., Trends Anal. Chem., J. Chromatogr. A), així com en revistes de química i materials d'àmbit multidisciplinari (Adv. Funct. Mater., Chem. Mater., ACS Appl. Mater. Interfaces, Chem. Commun., Chem. Eur. J.). Des de 2017 és membre del Consell Editorial Internacional de la revista Journal of Separation Science (Wiley).",
#   'CV_esp': 'Doctor en Química por la UIB (2011). Investigador postdoctoral/Fulbright Scholar en el Lawrence Berkeley National Laboratory (USA, 2012-2013). Ha realizado estancias de investigación en la University of Hull (UK), y ha sido investigador invitado por la University of Copenhagen (Dinamarca) y Fulbright Occasional Lecturer en la University of Minnesota Morris (USA). Su investigación se basa en el desarrollo de nuevos materiales y su integración sobre soportes funcionales, facilitando su uso para aplicaciones de separación química. Ha publicado 44 artículos en revistas internacionales del campo de la química analítica (Anal. Chem., Trends Anal. Chem., J. Chromatogr. A), así como en revistas de química y materiales de ámbito multidisciplinar (Adv. Funct. Mater., Chem. Mater., ACS Appl. Mater. Interfaces, Chem. Commun., Chem. Eur. J.). Desde 2017 es miembro del Consejo Editorial Internacional de la revista Journal of Separation Science (Wiley).',
#   'CV_eng': 'PhD Chemistry (UIB, 2011). Postdoctoral researcher / Fulbright Scholar at the Lawrence Berkeley National Laboratory (USA, 2012-2013). Visiting PhD student at the University of Hull (UK). Invited researcher at the University of Copenhagen (Denmark). Fulbright Occasional Lecturer at the University of Minnesota Morris (USA). His research is based on the development of new materials and their integration on functional supports, facilitating their use for chemical separations. Published 44 articles in international journals in the field of analytical chemistry (Anal. Chem., Trends Anal. Chem., J. Chromatogr. A), and in multidisciplinary chemistry or materials science journals (Adv. Funct. Mater., Chem. Mater., ACS Appl. Mater. Interfaces, Chem. Commun., Chem. Eur. J.). Member of the International Editorial Board of Journal of Separation Science (Wiley).'},
#  {'Grupo': 'Química de materials (MATER)',
#   'Nombre': 'Carlos Otero Areán',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Col·laboradors',
#   'Titulo': 'Dr.',
#   'Relacion UIB': 'Investigador Col·laborador de la UIB',
#   'CV_cat': 'No tiene CV en este idioma',
#   'CV_esp': 'No tiene CV en este idioma',
#   'CV_eng': 'No tiene CV en este idioma'},
#  {'Grupo': 'Química de materials (MATER)',
#   'Nombre': 'Andreu Figuerola Femenias',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Col·laboradors',
#   'Titulo': 'Sr.',
#   'Relacion UIB': 'Tècnic superior',
#   'CV_cat': 'No tiene CV en este idioma',
#   'CV_esp': 'No tiene CV en este idioma',
#   'CV_eng': 'No tiene CV en este idioma'},
#  {'Grupo': 'Química supramolecular (SUPRAMOL)',
#   'Nombre': 'Antonio Costa Torres',
#   'Genero': 'MASCULINO',
#   'Tipo de investigador': 'Investigador/a principal',
#   'Titulo': 'Dr.',
#   'Relacion UIB': "Catedràtic d'universitat",
#   'CV_cat': "El Dr. Antonio Costa es professor de l'àrea de coneixement de Química Orgànica (Departament de Química) de la UIB des de 1975. La seva recerca està relacionada amb Química supramolecular i el Reconeixement molecular amb molècules d'interès biològic i/o mediambiental. Pertany al grup de Química Supramolecular. Té concedits 6 quinquennis de docència i 6 sexennis d'investigació.",
#   'CV_esp': 'No existe CV en este idioma',
#   'CV_eng': 'No existe CV en este idioma'},
#  ...]

# %% [markdown]
# Para acabar, guardamos los datos en un fichero *.json*.

# %%
filename = 'Entrega_UIB_con_varios_cv.json'

# %%
dump_data(datos, filename)

# %% [markdown]
# Veamos cuantos elementos tiene nuestro conjunto de datos.

# %%
len(datos)
# Out:
# 2260
